# %% [markdown]
# # Data Structures
#
# Lists, tuples, sets, dictionaries.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ## Lists

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# List example

# %%
alist=[1,3,4]
blist=[1,3,2]
clist=alist+blist
print(clist)
# Out:
# [1, 3, 4, 1, 3, 2]

# %%
dmat=(alist,blist)
print(dmat)
# Out:
# ([1, 3, 4], [1, 3, 2])

# %%
for x in dmat:
    print(x)
    for y in x:
        print(y)
# Out:
# [1, 3, 4]
# 1
# 3
# 4
# [1, 3, 2]
# 1
# 3
# 2

# %%
stars = [ 'Alderaan', 'Arcturus', 'Vega']
len(stars)
# Out:
# 3

# %% [markdown]
# Accessing elements in the list with mylist[i] (with a from 0 to len(mylist)-1).

# %%
stars[2]
# Out:
# 'Vega'

# %% [markdown]
# Also we can use mylist[:i]

# %%
stars[:2]
# Out:
# ['Alderaan', 'Arcturus']

# %%
stars[2:]
# Out:
# ['Vega']

# %% [markdown]
# We can have nested lists within a list...

# %%
planets = [ ['Sol', 2], ['Sol', 3]]

planets[0][1]

# %% [markdown]
# ## Append
# Check if it changes the list or not!

# %%
alist.append(blist)
print(alist)
# Out:
# [1, 3, 4, [1, 3, 2], [1, 3, 2]]

# %% [markdown]
# ## Remove
# It removes the first element found.
# Check if it changes the list or not!

# %%
blist
# Out:
# [1]

# %%
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-17-57d7f17f1fad> in <module>
# ----> 1 cinco=blist.pop(1)
#       2 print(cinco)
#
# IndexError: pop index out of range

# %% [markdown]
# ## Count
# counting occurrences within the list

# %%
kk = ['perez', 'martinez', 'chope', 'polo', 'chope']

# %%
kk.count('chope')
# Out:
# 2

# %% [markdown]
# ## Index
# returning the index of the ocurrence.

# %%
kk.index('polo')
# Out:
# 3

# %% [markdown]
# ## Extend

# %% [markdown]
# __extend list by appending elements from the iterable__

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
stars.extend? #extend list by appending elements from the iterable

# %% [markdown]
# ## Adding and removing elements

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
stars
# Out:
# ['Alderaan', 'Arcturus']

# %%
stars.append('Vega')

# %%
stars
# Out:
# ['Alderaan', 'Arcturus', 'Vega']

# %%
stars
# Out:
# ['Alderaan', 'Arcturus', 'Vega']

# %%
stars

# %% [markdown]
# ### Example: removing a word in word list.

# %% [markdown]
# ## Reverse
# list.reverse() acts in place. But **reversed(list)** will reverse it only temporary, not altering the list.

# %%
# Out:
# ['Alderaan', 'Arcturus', 'Vega']

# %%
list(reversed(stars)) # --> reverse just the result not the data bellow
# Out:
# ['Vega', 'Arcturus', 'Alderaan']

# %% [markdown]
# ## Sort
# Try with strings, with mumber and mixing objects. Check keyword key: list.sort(key=str|int)
# ## Sorted
# sorted(list,key={function showing metric},reverse=False)

# %%
listNum= [4,1,3,42,4,5,5,4,3,3,45,6,4]
listNum.sort()
print(listNum)
# Out:
# [1, 3, 3, 3, 4, 4, 4, 4, 5, 5, 6, 42, 45]

# %%
listWords = ['foxes', 'hello', 'man', 'especulus']
listWords.sort()
print(listWords)
# Out:
# ['especulus', 'foxes', 'hello', 'man']

# %%
listWords.sort(key=str.lower,reverse=False)
print(listWords)
# Out:
# ['especulus', 'foxes', 'hello', 'man']

# %%
def countl(word):
    return word.count('l')

# %%
listWords.sort(key=countl)
print(listWords)
# Out:
# ['foxes', 'man', 'especulus', 'hello']

# %%
listWords.sort(key=lambda word:word.count('l'))
print(listWords)
# Out:
# ['foxes', 'man', 'especulus', 'hello']

# %% [markdown]
# **Exercise**: how to sort alphabetically but considering upper characters at same level than *lower*.
# pokemons = [Pikachu, Charmander, charizard, Jigglipuff, ekans, Ekans, Miaou]
# hint: use the right key function!

# %%
pokemons = ["Pikachu", "Charmander", "charizard", "Jigglipuff", "ekans", "Ekans", "Miaou"]
pokemons.sort()
print(pokemons)
# Out:
# ['Charmander', 'Ekans', 'Jigglipuff', 'Miaou', 'Pikachu', 'charizard', 'ekans']

# %% [markdown]
# ## Sort by custom function

# %% [markdown]
# __Anonimous or lambda functions__
# simple functions consisting of a single statement, the result of which is the return value.
# defined using the lambda keyword, which has no meaning other than “we are declaring an anonymous function.”

# %%
def short_function(x):
    return x *2

the_same_short_function=lambda x: x*2

# %%
short_function(4)

# %%
the_same_short_function(2)

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
def apply_to_list(some_list, some_function):
    results=[]
    for value in some_list:
        results.append(some_function(value))
    return results

ints=[1, 2, 3, 4]
apply_to_list(ints, lambda x:x*2)
# Out:
# [2, 4, 6, 8]

# %% [markdown]
# adding **for comprehension** we further reduce code

# %%
def apply_to_list2(some_list, some_function):
    return([some_function(x) for x in some_list]) 
ints=[1, 2, 3, 4]
apply_to_list2(ints, lambda x:x*3)
# Out:
# [3, 6, 9, 12]

# %% [markdown]
# Playing with this...

# %%
stars = [ 'Alderaan', 'Arcturus', 'Vega']
stars.append('AAaa')
stars.append('AAAAA')

# %%
stars.sort(key=lambda x:x.count('a'), reverse=True)
stars
# Out:
# ['Alderaan', 'AAaa', 'Vega', 'Arcturus', 'AAAAA']

# %%
stars.sort(key=lambda x:x.lower().count('a'), reverse=True) #No reverse = from less to more
stars
# Out:
# ['AAAAA', 'AAaa', 'Alderaan', 'Vega', 'Arcturus']

# %%
b=['aa','abs','abacus', 'bbb']

def length_str(str1):
    return len(str1)


b.sort(key=length_str)
b

# %%
stars.sort(key=lambda str1: len(str1))
stars

# %%
stars

# %% [markdown]
# # Functions as objects

# %% [markdown]
# __function is used as argument to other function
# ops has a list of the operations to apply to a particular set of values__

# %%
rmpf = 0
def myfunction(value):
    global kkk
    value+=value
    kkk=value

# %%
myfunction(3)
print(kkk)
# Out:
# 6

# %%
def add_one(value):
    return value+1
def double_value(value):
    return 2*value
def add_three(value):
    return value+3

math_ops =[add_one, double_value, add_three]

# %% [markdown]
# math_ops is a list of functions!
#
# Now we can define a function that takes a list of functions as input :)

# %%
def math_values(values,ops):
    result = []
    for value in values:
        for function in ops:
            value = function(value)
            result.append(value)
    return result

# %%
k=[1,2,3]
k_res=math_values(k,math_ops)
k_res

# %% [markdown]
# We can put this in the same list using append

# %%
k2=[]
for value in range(3):
    k2.append(k_res[value*3:(value+1)*3])

# %%
k2

# %% [markdown]
# Of course, we can give lambda functions...

# %%
math_values(k,[lambda x:x+1])

# %% [markdown]
# # Map

# %% [markdown]
# __map is built in function which applies a function to a collection of some kind__

# %%
k=[1,2,3]

# %%
for i in map(add_one,k):
    print (i)

# %%
k2=map(add_one,k)

# %%
type(k2)

# %%
list(k2)

# %% [markdown]
# These are techniques to apply function to element, column or dataframe.
#
# * **Map**: It iterates over each element of a series.
# df[‘column1’].map(lambda x: 10+x), this will add 10 to each element of column1.
# df[‘column2’].map(lambda x: ‘AV’+x), this will concatenate “AV“ at the beginning of each element of column2 (column format is string).
#
# * **Apply**: As the name suggests, applies a function along any axis of the DataFrame.
# df[[‘column1’,’column2’]].apply(sum), it will returns the sum of all the values of column1 and column2.
#
# * **ApplyMap**: This helps to apply a function to each element of dataframe.
# func = lambda x: x+2
# df.applymap(func), it will add 2 to each element of dataframe (all columns of dataframe must be numeric type)

# %% [markdown]
# # List comprehensions

# %% [markdown]
# * allow to concisely form a new list by filtering the elements of a collection and transforming the elements passing the filter in one concise expression.

# %%
a=[1,2,3,4, 5, 6]
result = []
for val in a:
    if val%2:
        result.append(val**2)
        
result

# %%
result2=[val**2 for val in a if val%2]
result2

# %%
result3=[val**2 if val%2 else 1 for val in a ] #--> changes the place for if condition
result3

# %%
def transform(x):
    if x==1: return 0
    elif x%2: return x**2
    else: return 1

result4=[transform(val) for val in a ]
result4

# %%
result5=map(transform,a)
list(result5)

# %%
strings=['a', 'as', 'bat', 'car', 'dove','python']
[x.upper() for x in strings if len(x)>2]

# %% [markdown]
# # Nested list Comprehension

# %% [markdown]
# * nested list comprehensions are a bit hard to wrap your head around.
# * The for parts of the list comprehension are arranged according to the order of nesting,
# * filter condition is put at the end as before.
# * example
#   * we “flatten” a list of tuples of integers into a simple list of integers:

# %%
some_tuples=[(1,2,3),(4,5,6),(7,8,9)]
flatten=[]
for tup in some_tuples:
    for element in tup:
        flatten.append(element)
flatten

# %%
some_tuples=[(1,2,3),(4,5,6),(7,8,9)]
#[ return_element for_loops_for_coming_to_element ]
flatten2=[element for tup in some_tuples for element in tup]
flatten2

# %% [markdown]
#   * Keep in mind that the order of the for expressions would be the same if you wrote a nested for loop instead of a list comprehension
