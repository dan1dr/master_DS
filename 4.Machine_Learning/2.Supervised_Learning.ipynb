# %% [markdown]
# # Ensemble Learning

# %% [markdown]
# We call __Ensemble Learning__ to the use of combination of simple models to create
# new models with better results than the simple ones.
#
# They can be used for Regression or Classification
#
# We can see that different models makes different predicitons that can differ

# %% [markdown]
# Ensemble Learning:
# - __Voting/Averaging__: Models are combined by taking the vote of each one or averaging the output of each model.Empirically, it does not give best results.
# - __Stacking__: Instead of simply averaging or voting, we can input the models prediction in a new machine learning model.
# - __Bagging__: Bagging consists in building several random datasets from the original one (different lines and features in each one) and using each one to train simple models (combined with average or vote).
# - __Random Forest__: It’s bagging with Decision Trees
# - __Gradient Boost__
#
# And:
# - Feature Preprocessing
# - Machine Learning Pipeline
# - Model Interpretability
# - AutoML

# %% [markdown]
# Types of combination:
#
# - __Parallel Combination__: We gather a group of experts in a room and ask them at the
# same time their opinion
#
# - __Sequential Combination__: We take 1 expert, ask for her prediction and calculate her
# mistake. We ask a new expert to predict this time the correction needed. Then the
# next one is asked the correction from the 2 previous experts ...

# %% [markdown]
# ## Voting

# %%
from sklearn.ensemble import VotingClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.svm import SVC

clf_v = VotingClassifier(estimators=[("DecTree",DecisionTreeClassifier(max_depth=3)),("RegLog",LogisticRegression()),("svm",SVC())])

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10, random_state=42)

# %%
clf_v.fit(X_train,y_train)
# Out:
# VotingClassifier(estimators=[('DecTree', DecisionTreeClassifier(max_depth=3)),
#                              ('RegLog', LogisticRegression()), ('svm', SVC())])

# %%
clf_v.predict([[.5,.6]])
# Out:
# array([1.])

# %% [markdown]
# ## Bagging

# %%
from sklearn.ensemble import BaggingClassifier
clf_b = BaggingClassifier(base_estimator=LogisticRegression(),n_estimators=100)
clf_b.fit(X_train,y_train)
# Out:
# c:\users\danid\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\danid\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %%
cross_val_score(clf_b,X,y)
# Out:
# c:\users\danid\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# c:\users\danid\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\linear_model\_logistic.py:763: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
# ...

# %% [markdown]
# ## Random Forest

# %%
import pandas as pd
# %pylab inline
df = pd.read_csv("https://raw.githubusercontent.com/rezpe/datos_viz/master/terrain.csv")
X = df[["bumpiness","grade"]]
y = df["target"]
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from sklearn.ensemble import RandomForestClassifier
clf = RandomForestClassifier(max_depth=4)
clf.fit(X,y)
# Out:
# RandomForestClassifier(max_depth=4)

# %%
cross_val_score(clf,X,y)
# Out:
# array([0.96666667, 0.96666667, 0.93333333, 0.93333333, 1.        ])

# %%
clf_r = RandomForestClassifier(n_estimators=100)
clf_r.fit(X,y)
# Out:
# RandomForestClassifier()

# %%
cross_val_score(clf_r,X,y)
# Out:
# array([0.96666667, 0.96666667, 0.93333333, 0.93333333, 1.        ])

# %%
clf_r.feature_importances_
# Out:
# array([0.10286553, 0.02561304, 0.4678293 , 0.40369213])

# %%
from sklearn.datasets import load_iris
from sklearn.ensemble import RandomForestClassifier
from sklearn.svm import LinearSVC
from sklearn.linear_model import LogisticRegression
from sklearn.preprocessing import StandardScaler
from sklearn.pipeline import make_pipeline
from sklearn.ensemble import StackingClassifier
X, y = load_iris(return_X_y=True)
estimators = [
('rf', RandomForestClassifier(n_estimators=10, random_state=42)),
('svr', LinearSVC(random_state=42))
]
clf = StackingClassifier(
estimators=estimators, final_estimator=LogisticRegression()
)
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, stratify=y, random_state=42)
clf.fit(X_train, y_train)
clf.score(X_test, y_test)
# Out:
# c:\users\danid\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# c:\users\danid\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# c:\users\danid\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# c:\users\danid\appdata\local\programs\python\python38-32\lib\site-packages\sklearn\svm\_base.py:985: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn("Liblinear failed to converge, increase "
# ...

# %% [markdown]
# ## Gradient Boosted Parameters

# %%
from sklearn.ensemble import GradientBoostingClassifier
clf = GradientBoostingClassifier(max_depth=4)
clf.fit(X,y)
# Out:
# GradientBoostingClassifier(max_depth=4)

# %%
cross_val_score(clf,X,y)
# Out:
# array([1.        , 0.96666667, 0.9       , 0.96666667, 1.        ])

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
clf_a = AdaBoostClassifier(base_estimator=LogisticRegression())
cross_val_score(clf_a,X,y)
# Out:
# array([0.93333333, 0.96666667, 0.9       , 0.93333333, 0.93333333])

# %%
from xgboost import XGBClassifier
clfxg=XGBClassifier(n_estimators=100,max_depth=4)
cross_val_score(clfxg,X,y)
clfxg.fit(X.values,y.values)
clfxg.predict([[0,1]])
clfxg.feature_importances_

# %% [markdown]
# # Advanced Regression sample

# %%
# %pylab inline
import pandas as pd
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_csv("https://raw.githubusercontent.com/rezpe/datos_viz/master/house_prices.csv")
df.head()
# Out:
#    Id  MSSubClass MSZoning  LotFrontage  LotArea Street Alley LotShape  \
# 0   1          60       RL         65.0     8450   Pave   NaN      Reg
# 1   2          20       RL         80.0     9600   Pave   NaN      Reg
# 2   3          60       RL         68.0    11250   Pave   NaN      IR1
# 3   4          70       RL         60.0     9550   Pave   NaN      IR1
# 4   5          60       RL         84.0    14260   Pave   NaN      IR1
#
#   LandContour Utilities  ... PoolArea PoolQC Fence MiscFeature MiscVal MoSold  \
# 0         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 1         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      5
# 2         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      9
# 3         Lvl    AllPub  ...        0    NaN   NaN         NaN       0      2
# 4         Lvl    AllPub  ...        0    NaN   NaN         NaN       0     12
#
#   YrSold  SaleType  SaleCondition  SalePrice
# ...

# %% [markdown]
# ## Building Gradient Boosting Trees example with only numeric features

# %%
df.columns[df.dtypes==int64]
# Out:
# Index(['Id', 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond',
#        'YearBuilt', 'YearRemodAdd', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
#        'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea',
#        'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
#        'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars',
#        'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
#        'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold', 'SalePrice'],
#       dtype='object')

# %%
X = df[[ 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond',
       'YearBuilt', 'YearRemodAdd', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
       'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea',
       'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
       'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars',
       'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
       'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']]
y = df['SalePrice']

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.10)
pred1 = y_train.mean()
pred1
# Out:
# 180896.32420091325

# %%
dfr = pd.DataFrame()
dfr['real'] = y_train
dfr['pred1'] = pred1
dfr.head()
# Out:
#         real          pred1
# 1246  186500  180896.324201
# 1056  185850  180896.324201
# 606   152000  180896.324201
# 352    95000  180896.324201
# 374   219500  180896.324201

# %%
dfr['resid1']=dfr['real']-dfr['pred1']
dfr.head()
# Out:
#         real          pred1        resid1
# 1246  186500  180896.324201   5603.675799
# 1056  185850  180896.324201   4953.675799
# 606   152000  180896.324201 -28896.324201
# 352    95000  180896.324201 -85896.324201
# 374   219500  180896.324201  38603.675799

# %%
# Load library
from sklearn.tree import DecisionTreeRegressor

# Create an instance
reg2 = DecisionTreeRegressor(max_depth=3)

# Fit the data
reg2.fit(X_train,dfr['resid1'])
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
dfr["pred2"]=dfr["pred1"]+0.1*reg2.predict(X_train)
dfr.head()
# Out:
#         real          pred1        resid1          pred2
# 1246  186500  180896.324201   5603.675799  182294.806734
# 1056  185850  180896.324201   4953.675799  182294.806734
# 606   152000  180896.324201 -28896.324201  175265.879719
# 352    95000  180896.324201 -85896.324201  175265.879719
# 374   219500  180896.324201  38603.675799  182294.806734

# %%
dfr["resid2"]=dfr["real"]-dfr["pred2"]
dfr.head()
# Out:
#         real          pred1        resid1          pred2        resid2
# 1246  186500  180896.324201   5603.675799  182294.806734   4205.193266
# 1056  185850  180896.324201   4953.675799  182294.806734   3555.193266
# 606   152000  180896.324201 -28896.324201  175265.879719 -23265.879719
# 352    95000  180896.324201 -85896.324201  175265.879719 -80265.879719
# 374   219500  180896.324201  38603.675799  182294.806734  37205.193266

# %%
from sklearn.tree import DecisionTreeRegressor
reg3 = DecisionTreeRegressor(max_depth=3)
reg3.fit(X_train,dfr['resid2'])
# Out:
# DecisionTreeRegressor(max_depth=3)

# %%
dfr["pred3"]=dfr["pred1"]+0.1*reg2.predict(X_train)+0.1*reg3.predict(X_train)
dfr["resid3"]=dfr["real"]-dfr["pred3"]
dfr.head()
# Out:
#         real          pred1        resid1          pred2        resid2  \
# 1246  186500  180896.324201   5603.675799  182294.806734   4205.193266
# 1056  185850  180896.324201   4953.675799  182294.806734   3555.193266
# 606   152000  180896.324201 -28896.324201  175265.879719 -23265.879719
# 352    95000  180896.324201 -85896.324201  175265.879719 -80265.879719
# 374   219500  180896.324201  38603.675799  182294.806734  37205.193266
#
#               pred3        resid3
# 1246  182931.602890   3568.397110
# 1056  182931.602890   2918.397110
# 606   170198.479684 -18198.479684
# 352   170198.479684 -75198.479684
# 374   187198.181550  32301.818450

# %%
pred_test2 = pred1 +0.1*reg2.predict(X_test)+0.1*reg3.predict(X_test)
pred_test1 = pred1 +0.1*reg2.predict(X_test)

# %%
from sklearn.metrics import mean_squared_error
np.sqrt(mean_squared_error(y_test,pred_test1))
# Out:
# 66817.03877446383

# %%
np.sqrt(mean_squared_error(y_test,pred_test2))
# Out:
# 62608.01256920444

# %%
from xgboost import XGBRegressor
from sklearn.ensemble import GradientBoostingRegressor

reg = GradientBoostingRegressor(max_depth=4, n_estimators=100,learning_rate=0.1)

# %%
from xgboost import XGBRegressor
from sklearn.ensemble import GradientBoostingRegressor

reg = GradientBoostingRegressor(max_depth=4, n_estimators=100,learning_rate=0.1)

# %%
from sklearn.model_selection import cross_val_score
cross_val_score(reg,X,y,scoring="neg_mean_absolute_error").mean()

# %%
from sklearn.model_selection import GridSearchCV
reg = GridSearchCV(GradientBoostingRegressor(n_estimators=50),
                  param_grid={"max_depth":np.arange(2,10),
                             "learning_rate":np.arange(1,10)/10},
                  scoring="neg_mean_absolute_error",
                  cv=5)

reg.fit(X,y)
reg

# %% [markdown]
# ## Outliers

# %% [markdown]
# Their inclusion is up to the
# data scientist, but it is recommended
# to have a separate model
# for them

# %%
plt.scatter(df['GrLivArea'],df['SalePrice'])

# %%
plt.hist(df['SalePrice'])
# Out:
# (array([148., 723., 373., 135.,  51.,  19.,   4.,   3.,   2.,   2.]),
#  array([ 34900., 106910., 178920., 250930., 322940., 394950., 466960.,
#         538970., 610980., 682990., 755000.]),
#  <BarContainer object of 10 artists>)

# %%
df = df[df['GrLivArea']<4000]
plt.scatter(df['GrLivArea'],df['SalePrice'])

# %% [markdown]
# ## Transforming the output value

# %% [markdown]
# __Multiplicative Distribution__. It is better to transform
# multiplicative distribution
# features as there are intervals
# with low number of samples

# %%
plt.hist(df['SalePrice'])
# Out:
# (array([ 96., 539., 445., 211.,  96.,  37.,  20.,   6.,   3.,   3.]),
#  array([ 34900.,  93910., 152920., 211930., 270940., 329950., 388960.,
#         447970., 506980., 565990., 625000.]),
#  <BarContainer object of 10 artists>)

# %%
df["SalePrice"]=np.log1p(df["SalePrice"])
plt.hist(df["SalePrice"]);

# %% [markdown]
# __Skewed Distribution Values__. Skewed Distribution
# can complicate the analysis
# for some ML models

# %% [markdown]
# ## Missing values

# %% [markdown]
# Visit https://github.com/ResidentMario/missingno
#
# Imputation is the process of replacing missing data. Some strategies:
#
# - Interpolation (Time Series): Taking the value of nearest non-missing and calculate average.
# - New category or value: Missing is a category
# - Most Common: Replace with the most common
# - Most common from category: Taking the nearest per another category

# %%
df.columns[df.isnull().sum()!=0]
# Out:
# Index(['LotFrontage', 'Alley', 'MasVnrType', 'MasVnrArea', 'BsmtQual',
#        'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
#        'Electrical', 'FireplaceQu', 'GarageType', 'GarageYrBlt',
#        'GarageFinish', 'GarageQual', 'GarageCond', 'PoolQC', 'Fence',
#        'MiscFeature'],
#       dtype='object')

# %%
# Missing means none
for col in ["PoolQC","MiscFeature","Alley","Fence","FireplaceQu",
            'GarageType', 'GarageFinish', 'GarageQual', 'GarageCond',
           'BsmtQual', 'BsmtCond', 'BsmtExposure', 'BsmtFinType1', 'BsmtFinType2',
           "MasVnrType",
           'MSSubClass']:
    df[col]=df[col].fillna("None")

# %%
# Missing means 0
for col in ['GarageYrBlt', 'GarageArea', 'GarageCars',
           'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF','TotalBsmtSF', 'BsmtFullBath', 'BsmtHalfBath',
           "MasVnrArea"]:
    df[col]=df[col].fillna(0)

# %%
df.columns[df.isnull().sum()!=0]
# Out:
# Index(['LotFrontage', 'Electrical'], dtype='object')

# %%
df["LotFrontage"]=df.groupby("Neighborhood")["LotFrontage"].transform(lambda x:x.fillna(x.median()))
df["Electrical"]=df["Electrical"].fillna(df["Electrical"].mode()[0])
df.columns[df.isnull().sum()!=0]
# Out:
# Index([], dtype='object')

# %% [markdown]
# ## Scaling variables

# %% [markdown]
# Different features might have different units and orders of magnitude. Scaling puts
# all of them in the same order of magnitude.
#
# - Min-Max scaling
# - Standard Scaling (https://towardsdatascience.com/normalization-vs-standardization-quantitative-analysis-a91e8a79cebf)
# - Robust scaling

# %%
from sklearn.preprocessing import RobustScaler

# %%
rbs = RobustScaler()
X = df[[ 'MSSubClass', 'LotArea', 'OverallQual', 'OverallCond',
       'YearBuilt', 'YearRemodAdd', 'BsmtFinSF1', 'BsmtFinSF2', 'BsmtUnfSF',
       'TotalBsmtSF', '1stFlrSF', '2ndFlrSF', 'LowQualFinSF', 'GrLivArea',
       'BsmtFullBath', 'BsmtHalfBath', 'FullBath', 'HalfBath', 'BedroomAbvGr',
       'KitchenAbvGr', 'TotRmsAbvGrd', 'Fireplaces', 'GarageCars',
       'GarageArea', 'WoodDeckSF', 'OpenPorchSF', 'EnclosedPorch', '3SsnPorch',
       'ScreenPorch', 'PoolArea', 'MiscVal', 'MoSold', 'YrSold']]

# %%
X_scale = rbs.fit_transform(X)
X[:5]
# Out:
#    MSSubClass  LotArea  OverallQual  OverallCond  YearBuilt  YearRemodAdd  \
# 0          60     8450            7            5       2003          2003
# 1          20     9600            6            8       1976          1976
# 2          60    11250            7            5       2001          2002
# 3          70     9550            7            5       1915          1970
# 4          60    14260            8            5       2000          2000
#
#    BsmtFinSF1  BsmtFinSF2  BsmtUnfSF  TotalBsmtSF  ...  GarageArea  \
# 0         706           0        150          856  ...         548
# 1         978           0        284         1262  ...         460
# 2         486           0        434          920  ...         608
# 3         216           0        540          756  ...         642
# 4         655           0        490         1145  ...         836
#
#    WoodDeckSF  OpenPorchSF  EnclosedPorch  3SsnPorch  ScreenPorch  PoolArea  \
# ...

# %%
X_scale[:5]
# Out:
# array([[ 2.00000000e-01, -2.51528061e-01,  5.00000000e-01,
#          0.00000000e+00,  6.73913043e-01,  2.55033557e-01,
#          4.60014154e-01,  0.00000000e+00, -5.59350982e-01,
#         -2.69674185e-01, -4.53425333e-01,  1.17307692e+00,
#          0.00000000e+00,  3.88567014e-01,  1.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  1.00000000e+00,
#         -1.00000000e+00,  0.00000000e+00,  2.81947262e-01,
#          0.00000000e+00,  5.44117647e-01,  0.00000000e+00,
#          0.00000000e+00,  0.00000000e+00,  0.00000000e+00,
#          0.00000000e+00, -1.33333333e+00,  0.00000000e+00],
#        [-6.00000000e-01,  3.24751497e-02,  0.00000000e+00,
#          3.00000000e+00,  8.69565217e-02, -4.69798658e-01,
#          8.45010616e-01,  0.00000000e+00, -3.30486763e-01,
#          5.44360902e-01,  3.46968950e-01,  0.00000000e+00,
#          0.00000000e+00, -3.03592121e-01,  0.00000000e+00,
# ...

# %% [markdown]
# ## Categorical Features

# %% [markdown]
# Categorical features can not be feed directly to a machine learning model. They
# need to be converted to a number of vector.
#
# Some strategies:
# - One-hot encoding: We add a column per feature category
# - Weight: We replace the category by a number (sum of target class or mean of
# target)
# - Embedding: We replace the category with a vector

# %%
dfb = pd.get_dummies(df)
len(dfb.columns)
# Out:
# 303

# %%
dfb.head()
# Out:
#    Id  MSSubClass  LotFrontage  LotArea  OverallQual  OverallCond  YearBuilt  \
# 0   1          60         65.0     8450            7            5       2003
# 1   2          20         80.0     9600            6            8       1976
# 2   3          60         68.0    11250            7            5       2001
# 3   4          70         60.0     9550            7            5       1915
# 4   5          60         84.0    14260            8            5       2000
#
#    YearRemodAdd  MasVnrArea  BsmtFinSF1  ...  SaleType_ConLw  SaleType_New  \
# 0          2003       196.0         706  ...               0             0
# 1          1976         0.0         978  ...               0             0
# 2          2002       162.0         486  ...               0             0
# 3          1970         0.0         216  ...               0             0
# 4          2000       350.0         655  ...               0             0
#
# ...

# %%
df["SaleCondition"].unique()
df[df["SaleCondition"]=='Partial']["SalePrice"].mean()
dfb = pd.get_dummies(df)
X=dfb[list(set(dfb.columns)-set(["Id","SalePrice"]))]
y=dfb["SalePrice"]

# %% [markdown]
# ## Machine Learning Pipelines

# %% [markdown]
# Preprocessing and Machine Learning Models can be integrated in a single model.
# This model is called a pipeline. All data processing is a pipeline.
#
# The directed graph shell, dgsh (pronounced /dæɡʃ/ — dagsh), provides an expressive way to construct sophisticated and efficient big data set and stream processing pipelines using existing Unix tools as well as custom-built components. It is a Unix-style shell (based on bash https://www.spinellis.gr/sw/dgsh/

# %%
rbs = RobustScaler()
X_scaled = rbs.fit_transform(X)

# %%
from sklearn.ensemble import RandomForestRegressor
reg = RandomForestRegressor(max_depth=4)

# %%
cross_val_score(reg,X_scaled,y,scoring = 'neg_mean_absolute_error')
# Out:
# array([-0.12208849, -0.12325289, -0.12657033, -0.12123607, -0.12238743])

# %%
from sklearn.pipeline import Pipeline

pipe = Pipeline(steps=[("scaled",RobustScaler()),("rf",RandomForestRegressor(max_depth=4))])

# %%
cross_val_score(pipe,X,y,scoring="neg_mean_absolute_error")
# Out:
# array([-0.12355423, -0.12418468, -0.12780269, -0.1228081 , -0.12123507])

# %%
import pickle

pickle.dump(pipe,open("pipe.pkl","wb"))
reg.fit(X,y)
# Out:
# RandomForestRegressor(max_depth=4)

# %% [markdown]
# ## Model Interpretability

# %% [markdown]
# __Tree Based Models__
#
# Variables in the tree are of higher importance and prioritized
#
# __Permutation Importance__
#
# __Partial Dependence Plot__
#
# Effect of the variable on the target if all the other features were kept the same
#
# __Shap Values__
#
# Shap values provide the effect of the different feature for a specific prediction:
# ````
# sum(SHAP values for all features) = pred_for_team - pred_for_baseline_values
#
# ````

# %% [markdown]
# ## Feature Importances

# %%
plt.plot(reg.feature_importances_)

# %%
X.columns[reg.feature_importances_>0.01]
# Out:
# Index(['BsmtFinSF1', 'TotalBsmtSF', 'GarageArea', 'YearBuilt', 'GrLivArea',
#        'OverallQual', '1stFlrSF', 'GarageCars'],
#       dtype='object')

# %% [markdown]
# ## AutoML

# %% [markdown]
# Several companies/libraries offer the promise of an automated machine learning
# modelling:
# - Massively try different models and approach
# - Tweaks the parameters to get to the best result
#
# *All those approaches can not replace Data Scientist expertise especially on
# feature engineering.*

# %% [markdown]
# About hyperparameter optimisation https://towardsdatascience.com/hyperparameter-optimization-with-scikit-learn-scikit-opt-and-keras-f13367f3e796
