# %% [markdown]
# __Clean, Transform, Merge and Reshape__

# %% [markdown]
# Pandas provides a high-level, flexible, and high-performance set of core manipulations and algorithms to enable you to wrangle data into the right form.

# %% [markdown]
# # Combining and Merging Data Sets

# %% [markdown]
# `pandas.merge` connects rows in DataFrame based on one or more keys.
#
# `pandas.concat` stacks together objects along an axis.
#
# `combine_first` instance method enables splicing together overlapping data to fill in missing values in one object with values from another.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use('seaborn')
# %matplotlib inline

# %% [markdown]
# ## Database-style DataFrame Merges

# %%
left = pd.DataFrame({'data1' : np.random.randint(100, 200, 8), 'key' : list('bacbaacb')})
right = pd.DataFrame({'data2' : np.random.randint(10, 99, 7), 'key' : list('acaacdd')})
right
# Out:
#    data2 key
# 0     93   a
# 1     31   c
# 2     49   a
# 3     53   a
# 4     46   c
# 5     86   d
# 6     43   d

# %%
left.merge(right)
# Out:
#     data1 key  data2
# 0     147   a     93
# 1     147   a     49
# 2     147   a     53
# 3     135   a     93
# 4     135   a     49
# 5     135   a     53
# 6     189   a     93
# 7     189   a     49
# 8     189   a     53
# 9     120   c     31
# 10    120   c     46
# 11    140   c     31
# 12    140   c     46

# %%
pd.merge(left, right, on = 'key')
# Out:
#     data1 key  data2
# 0     147   a     93
# 1     147   a     49
# 2     147   a     53
# 3     135   a     93
# 4     135   a     49
# 5     135   a     53
# 6     189   a     93
# 7     189   a     49
# 8     189   a     53
# 9     120   c     31
# 10    120   c     46
# 11    140   c     31
# 12    140   c     46

# %% [markdown]
# By default, `merge` does an 'inner' join (intersection). Other possibilities are `left`, `right`, and `outer`

# %%
left.merge(right, how = 'left')
# or pd.merge(left,right, how = 'left')
# Out:
#     data1 key  data2
# 0     158   b    NaN
# 1     147   a   93.0
# 2     147   a   49.0
# 3     147   a   53.0
# 4     120   c   31.0
# 5     120   c   46.0
# 6     158   b    NaN
# 7     135   a   93.0
# 8     135   a   49.0
# 9     135   a   53.0
# 10    189   a   93.0
# 11    189   a   49.0
# 12    189   a   53.0
# 13    140   c   31.0
# 14    140   c   46.0
# 15    180   b    NaN

# %%
left.merge(right, how = 'outer')
# Out:
#     data1 key  data2
# 0   158.0   b    NaN
# 1   158.0   b    NaN
# 2   180.0   b    NaN
# 3   147.0   a   93.0
# 4   147.0   a   49.0
# 5   147.0   a   53.0
# 6   135.0   a   93.0
# 7   135.0   a   49.0
# 8   135.0   a   53.0
# 9   189.0   a   93.0
# 10  189.0   a   49.0
# 11  189.0   a   53.0
# 12  120.0   c   31.0
# 13  120.0   c   46.0
# 14  140.0   c   31.0
# 15  140.0   c   46.0
# 16    NaN   d   86.0
# 17    NaN   d   43.0

# %% [markdown]
# It returns the carteasian product of the elements with common keys, if there are duplicates, then it will return all the posible combinations.
#
# If columns don't have the same name, or we want to join the index of the DataFrames, we will need to specify that.

# %%
right.columns = ['a', 'b']
left.merge(right, left_on = ['key'], right_on = ['b'])
# Out:
#     data1 key   a  b
# 0     147   a  93  a
# 1     147   a  49  a
# 2     147   a  53  a
# 3     135   a  93  a
# 4     135   a  49  a
# 5     135   a  53  a
# 6     189   a  93  a
# 7     189   a  49  a
# 8     189   a  53  a
# 9     120   c  31  c
# 10    120   c  46  c
# 11    140   c  31  c
# 12    140   c  46  c

# %% [markdown]
# If there are two columns with the same name that we do not join on, both will get transferred to the resulting DataFrame with a suffix. We can customize these suffixes.

# %%
right.columns = ['data1', 'key']
left.merge(right, left_on=['key'], right_on=['key'])
# Out:
#     data1_x key  data1_y
# 0       147   a       93
# 1       147   a       49
# 2       147   a       53
# 3       135   a       93
# 4       135   a       49
# 5       135   a       53
# 6       189   a       93
# 7       189   a       49
# 8       189   a       53
# 9       120   c       31
# 10      120   c       46
# 11      140   c       31
# 12      140   c       46

# %%
left.merge(right, left_on=['key'], right_on=['key'], suffixes=['_chachi', '_piruli'])
# Out:
#     data1_chachi key  data1_piruli
# 0            147   a            93
# 1            147   a            49
# 2            147   a            53
# 3            135   a            93
# 4            135   a            49
# 5            135   a            53
# 6            189   a            93
# 7            189   a            49
# 8            189   a            53
# 9            120   c            31
# 10           120   c            46
# 11           140   c            31
# 12           140   c            46

# %% [markdown]
# ## Merging on Index

# %% [markdown]
# ``left_index = True`` or ``right_index = True`` (or both) to indicate that the index should be used as the merge key.

# %%
right.index = list('abdoier')
right
# Out:
#    data1 key
# a     93   a
# b     31   c
# d     49   a
# o     53   a
# i     46   c
# e     86   d
# r     43   d

# %%
left.merge(right, left_on = 'key', right_index = True, how = 'outer')
# Out:
#     key  data1_x key_x  data1_y key_y
# 0.0   b    158.0     b     31.0     c
# 3.0   b    158.0     b     31.0     c
# 7.0   b    180.0     b     31.0     c
# 1.0   a    147.0     a     93.0     a
# 4.0   a    135.0     a     93.0     a
# 5.0   a    189.0     a     93.0     a
# 2.0   c    120.0     c      NaN   NaN
# 6.0   c    140.0     c      NaN   NaN
# NaN   d      NaN   NaN     49.0     a
# NaN   o      NaN   NaN     53.0     a
# NaN   i      NaN   NaN     46.0     c
# NaN   e      NaN   NaN     86.0     d
# NaN   r      NaN   NaN     43.0     d

# %% [markdown]
# ## Concatenating along an axis

# %% [markdown]
# Use ``concatenate`` function

# %%
pd.concat([left, right])
# Out:
#    data1 key
# 0    158   b
# 1    147   a
# 2    120   c
# 3    158   b
# 4    135   a
# 5    189   a
# 6    140   c
# 7    180   b
# a     93   a
# b     31   c
# d     49   a
# o     53   a
# i     46   c
# e     86   d
# r     43   d

# %% [markdown]
# By default `concat` works along axis=0 producing another Series. With axis=1, the result is a DataFrame.

# %%
pd.concat([left, right], axis = 1)
# Out:
#    data1  key  data1  key
# 0  158.0    b    NaN  NaN
# 1  147.0    a    NaN  NaN
# 2  120.0    c    NaN  NaN
# 3  158.0    b    NaN  NaN
# 4  135.0    a    NaN  NaN
# 5  189.0    a    NaN  NaN
# 6  140.0    c    NaN  NaN
# 7  180.0    b    NaN  NaN
# a    NaN  NaN   93.0    a
# b    NaN  NaN   31.0    c
# d    NaN  NaN   49.0    a
# e    NaN  NaN   86.0    d
# i    NaN  NaN   46.0    c
# o    NaN  NaN   53.0    a
# r    NaN  NaN   43.0    d

# %% [markdown]
# DataFrames in which the row index does not contain any relevant data can be ignored with ``ignore_index = True``

# %%
df1 = pd.DataFrame(np.random.randn(3, 4), columns = ['a', 'b', 'c', 'd'])
df2 = pd.DataFrame(np.random.randn(2, 3), columns = ['b', 'd', 'a'])

pd.concat([df1, df2], ignore_index = True)
# Out:
#           a         b         c         d
# 0  0.120008 -0.334133 -1.603482  0.423033
# 1 -1.665532 -0.180863 -1.501919 -0.439324
# 2  0.352375  1.614360  0.803241 -1.227213
# 3  1.174486 -0.566006       NaN  0.540353
# 4 -0.541470 -0.488286       NaN -1.191316

# %% [markdown]
# # Reshaping and Pivoting

# %% [markdown]
# Number of basic operations for rearranging tabular data.

# %% [markdown]
# ## Reshaping with Hierarchical Indexing

# %% [markdown]
# ``stack`` rotates or pivots from the columns in the data to the rows.
#
# ``unstack`` pivots from the rows into the columns.

# %%
data = pd.DataFrame(np.arange(6).reshape((2, 3)),
                   index = pd.Index(['Ohio', 'Colorado'], name = 'state'),
                   columns = pd.Index(['one', 'two', 'three'],
                                     name = 'number'))
data
# Out:
# number    one  two  three
# state
# Ohio        0    1      2
# Colorado    3    4      5

# %%
result = data.stack()
result
# Out:
# state     number
# Ohio      one       0
#           two       1
#           three     2
# Colorado  one       3
#           two       4
#           three     5
# dtype: int32

# %%
result.unstack()
# Out:
# number    one  two  three
# state
# Ohio        0    1      2
# Colorado    3    4      5

# %%
result.unstack(0)
# Out:
# state   Ohio  Colorado
# number
# one        0         3
# two        1         4
# three      2         5

# %%
result.unstack('state')
# Out:
# state   Ohio  Colorado
# number
# one        0         3
# two        1         4
# three      2         5

# %%
df = pd.DataFrame({'left': result, 'right': result + 5},
                 columns = pd.Index(['left', 'right'], name = 'side'))

df
# Out:
# side             left  right
# state    number
# Ohio     one        0      5
#          two        1      6
#          three      2      7
# Colorado one        3      8
#          two        4      9
#          three      5     10

# %%
df.unstack(0).stack(0)
# Out:
# state         Colorado  Ohio
# number side
# one    left          3     0
#        right         8     5
# two    left          4     1
#        right         9     6
# three  left          5     2
#        right        10     7

# %% [markdown]
# ### Example

# %% [markdown]
# Data from https://www.transtats.bts.gov/

# %%
# !unzip /home/dsc/Downloads/On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2020_3.zip
# Out:
# Archive:  /home/dsc/Downloads/On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2020_3.zip
#   inflating: On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2020_3.csv
#   inflating: readme.html

# %%
# !head readme.html
# Out:
# <HTML>
# <HEAD>
# 	<TITLE> readme.html </TITLE>
# </HEAD>
# <BODY>
# 	<TABLE><TR><TD COLSPAN=2><H4>BACKGROUND</H4></TD></TR>
# 	<TR><TD COLSPAN=2>The data contained in the compressed file has been extracted from the
# 	Reporting Carrier On-Time Performance (1987-present) data table of the "On-Time" database from the TranStats data library.
# 	The time period is indicated in the name of the compressed file;
# 	for example, XXX_XXXXX_2001_1 contains data of the first month of the year 2001. </TD></TR>

# %% [markdown]
# We can display the contents of the __readme.html__ within the notebook with Ipython.display.IFrame

# %%
from IPython.display import IFrame
import pandas as pd

IFrame('http://elpais.com', 800, 300)
# Out:
#         <iframe
#             width="800"
#             height="300"
#             src="http://elpais.com"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %%
IFrame('readme.html', 800, 300)
# Out:
#         <iframe
#             width="800"
#             height="300"
#             src="readme.html"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# We can open the files without decompressing them. Use [zipfile](https://docs.python.org/3/library/zipfile.html)

# %%
from zipfile import ZipFile

zfile = ZipFile('/home/dsc/Downloads/On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2020_3.zip')
zfile.filelist
# Out:
# [<ZipInfo filename='On_Time_Reporting_Carrier_On_Time_Performance_(1987_present)_2020_3.csv' compress_type=deflate filemode='-rw-r--r--' file_size=284488780 compress_size=30367345>,
#  <ZipInfo filename='readme.html' compress_type=deflate filemode='-rw-r--r--' file_size=12152 compress_size=2244>]

# %% [markdown]
# zip_file connect the compressed file. We can use it to open a connection to one of the files it contains.

# %%
csvfile = zfile.open(zfile.filelist[0])
csvfile.readline()
# Out:
# b'"Year","Quarter","Month","DayofMonth","DayOfWeek","FlightDate","Reporting_Airline","DOT_ID_Reporting_Airline","IATA_CODE_Reporting_Airline","Tail_Number","Flight_Number_Reporting_Airline","OriginAirportID","OriginAirportSeqID","OriginCityMarketID","Origin","OriginCityName","OriginState","OriginStateFips","OriginStateName","OriginWac","DestAirportID","DestAirportSeqID","DestCityMarketID","Dest","DestCityName","DestState","DestStateFips","DestStateName","DestWac","CRSDepTime","DepTime","DepDelay","DepDelayMinutes","DepDel15","DepartureDelayGroups","DepTimeBlk","TaxiOut","WheelsOff","WheelsOn","TaxiIn","CRSArrTime","ArrTime","ArrDelay","ArrDelayMinutes","ArrDel15","ArrivalDelayGroups","ArrTimeBlk","Cancelled","CancellationCode","Diverted","CRSElapsedTime","ActualElapsedTime","AirTime","Flights","Distance","DistanceGroup","CarrierDelay","WeatherDelay","NASDelay","SecurityDelay","LateAircraftDelay","FirstDepTime","TotalAddGTime","LongestAddGTime","DivAirportLandings","DivReachedDest","DivActualElapsedTime","DivArrDelay","DivDistance","Div1Airport","Div1AirportID","Div1AirportSeqID","Div1WheelsOn","Div1TotalGTime","Div1LongestGTime","Div1WheelsOff","Div1TailNum","Div2Airport","Div2AirportID","Div2AirportSeqID","Div2WheelsOn","Div2TotalGTime","Div2LongestGTime","Div2WheelsOff","Div2TailNum","Div3Airport","Div3AirportID","Div3AirportSeqID","Div3WheelsOn","Div3TotalGTime","Div3LongestGTime","Div3WheelsOff","Div3TailNum","Div4Airport","Div4AirportID","Div4AirportSeqID","Div4WheelsOn","Div4TotalGTime","Div4LongestGTime","Div4WheelsOff","Div4TailNum","Div5Airport","Div5AirportID","Div5AirportSeqID","Div5WheelsOn","Div5TotalGTime","Div5LongestGTime","Div5WheelsOff","Div5TailNum",\n'

# %% [markdown]
# Now we can load the file into memory as a pandas dataframe. Remember to close the connection to the files.

# %%
flights = pd.read_csv(csvfile)
# Out:
# /home/dsc/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (48,69,76,77,84) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
pd.options.display.max_columns = None

flights.shape
# Out:
# (648228, 110)

# %%
flights.sample(4)
# Out:
#         2020  1  3   9  1.1  2020-03-09  9E  20363 9E.1  N669CA  4677  11433  \
# 231359  2020  1  3  23    1  2020-03-23  DL  19790   DL  N550NW  2494  10397
# 303630  2020  1  3  17    2  2020-03-17  MQ  20398   MQ  N677AE  3973  11996
# 463287  2020  1  3   2    1  2020-03-02  YX  20452   YX  N119HQ  4460  14122
# 62928   2020  1  3  12    4  2020-03-12  AA  19805   AA  N537UW  1770  14635
#
#         1143302  31295  DTW     Detroit, MI  MI  26        Michigan  43  \
# 231359  1039707  30397  ATL     Atlanta, GA  GA  13         Georgia  34
# 303630  1199603  31871  GSP       Greer, SC  SC  45  South Carolina  37
# 463287  1412202  30198  PIT  Pittsburgh, PA  PA  42    Pennsylvania  23
# 62928   1463502  31714  RSW  Fort Myers, FL  FL  12         Florida  33
#
#         14307  1430705  30721  PVD       Providence, RI  RI  44  \
# 231359  11697  1169706  32467  FLL  Fort Lauderdale, FL  FL  12
# 303630  13930  1393007  30977  ORD          Chicago, IL  IL  17
# 463287  12953  1295304  31703  LGA         New York, NY  NY  36
# 62928   11057  1105703  31057  CLT        Charlotte, NC  NC  37
#
#           Rhode Island  15  1423   1412  -11.00  0.00  0.00.1   -1  1400-1459  \
# 231359         Florida  33  1218    NaN     NaN   NaN     NaN  NaN  1200-1259
# 303630        Illinois  41   735  729.0    -6.0   0.0     0.0 -1.0  0700-0759
# 463287        New York  22   600  552.0    -8.0   0.0     0.0 -1.0  0600-0659
# 62928   North Carolina  36   651  645.0    -6.0   0.0     0.0 -1.0  0600-0659
#
#         16.00   1428   1552  5.00  1615   1557  -18.00  0.00.2  0.00.3   -2  \
# 231359    NaN    NaN    NaN   NaN  1410    NaN     NaN     NaN     NaN  NaN
# 303630   32.0  801.0  837.0  12.0   852  849.0    -3.0     0.0     0.0 -1.0
# 463287   16.0  608.0  705.0   8.0   740  713.0   -27.0     0.0     0.0 -2.0
# 62928    10.0  655.0  824.0  13.0   850  837.0   -13.0     0.0     0.0 -1.0
#
#         1600-1659  0.00.4 Unnamed: 48  0.00.5  112.00  105.00  84.00  1.00  \
# 231359  1400-1459     1.0           D     0.0   112.0     NaN    NaN   1.0
# 303630  0800-0859     0.0         NaN     0.0   137.0   140.0   96.0   1.0
# 463287  0700-0759     0.0         NaN     0.0   100.0    81.0   57.0   1.0
# 62928   0800-0859     0.0         NaN     0.0   119.0   112.0   89.0   1.0
#
#         615.00  3.1  Unnamed: 56  Unnamed: 57  Unnamed: 58  Unnamed: 59  \
# 231359   581.0    3          NaN          NaN          NaN          NaN
# 303630   577.0    3          NaN          NaN          NaN          NaN
# 463287   335.0    2          NaN          NaN          NaN          NaN
# 62928    600.0    3          NaN          NaN          NaN          NaN
#
#         Unnamed: 60  Unnamed: 61  Unnamed: 62  Unnamed: 63    0  Unnamed: 65  \
# 231359          NaN          NaN          NaN          NaN  0.0          NaN
# 303630          NaN          NaN          NaN          NaN  0.0          NaN
# 463287          NaN          NaN          NaN          NaN  0.0          NaN
# 62928           NaN          NaN          NaN          NaN  0.0          NaN
#
#         Unnamed: 66  Unnamed: 67  Unnamed: 68 Unnamed: 69  Unnamed: 70  \
# 231359          NaN          NaN          NaN         NaN          NaN
# 303630          NaN          NaN          NaN         NaN          NaN
# 463287          NaN          NaN          NaN         NaN          NaN
# 62928           NaN          NaN          NaN         NaN          NaN
#
#         Unnamed: 71  Unnamed: 72  Unnamed: 73  Unnamed: 74  Unnamed: 75  \
# 231359          NaN          NaN          NaN          NaN          NaN
# 303630          NaN          NaN          NaN          NaN          NaN
# 463287          NaN          NaN          NaN          NaN          NaN
# 62928           NaN          NaN          NaN          NaN          NaN
#
#        Unnamed: 76 Unnamed: 77  Unnamed: 78  Unnamed: 79  Unnamed: 80  \
# 231359         NaN         NaN          NaN          NaN          NaN
# 303630         NaN         NaN          NaN          NaN          NaN
# 463287         NaN         NaN          NaN          NaN          NaN
# 62928          NaN         NaN          NaN          NaN          NaN
#
#         Unnamed: 81  Unnamed: 82  Unnamed: 83 Unnamed: 84  Unnamed: 85  \
# 231359          NaN          NaN          NaN         NaN          NaN
# 303630          NaN          NaN          NaN         NaN          NaN
# 463287          NaN          NaN          NaN         NaN          NaN
# 62928           NaN          NaN          NaN         NaN          NaN
#
#         Unnamed: 86  Unnamed: 87  Unnamed: 88  Unnamed: 89  Unnamed: 90  \
# 231359          NaN          NaN          NaN          NaN          NaN
# 303630          NaN          NaN          NaN          NaN          NaN
# 463287          NaN          NaN          NaN          NaN          NaN
# 62928           NaN          NaN          NaN          NaN          NaN
#
#         Unnamed: 91  Unnamed: 92  Unnamed: 93  Unnamed: 94  Unnamed: 95  \
# 231359          NaN          NaN          NaN          NaN          NaN
# 303630          NaN          NaN          NaN          NaN          NaN
# 463287          NaN          NaN          NaN          NaN          NaN
# 62928           NaN          NaN          NaN          NaN          NaN
#
#         Unnamed: 96  Unnamed: 97  Unnamed: 98  Unnamed: 99  Unnamed: 100  \
# 231359          NaN          NaN          NaN          NaN           NaN
# 303630          NaN          NaN          NaN          NaN           NaN
# 463287          NaN          NaN          NaN          NaN           NaN
# 62928           NaN          NaN          NaN          NaN           NaN
#
#         Unnamed: 101  Unnamed: 102  Unnamed: 103  Unnamed: 104  Unnamed: 105  \
# 231359           NaN           NaN           NaN           NaN           NaN
# 303630           NaN           NaN           NaN           NaN           NaN
# 463287           NaN           NaN           NaN           NaN           NaN
# 62928            NaN           NaN           NaN           NaN           NaN
#
#         Unnamed: 106  Unnamed: 107  Unnamed: 108  Unnamed: 109
# 231359           NaN           NaN           NaN           NaN
# 303630           NaN           NaN           NaN           NaN
# 463287           NaN           NaN           NaN           NaN
# 62928            NaN           NaN           NaN           NaN

# %%
import time
import tqdm

x = 0

for i in tqdm.tqdm(range(100)):
    time.sleep(.01)
    x += i
    
i
# Out:
# 100%|██████████| 100/100 [00:01<00:00, 86.67it/s]
# 99

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 648228 entries, 0 to 648227
# Columns: 110 entries, 2020 to Unnamed: 109
# dtypes: float64(71), int64(20), object(19)
# memory usage: 544.0+ MB

# %% [markdown]
# Let's load March and April 2020 into a single DataFrame

# %%
dfs = []

for name in ['/home/dsc/Downloads/On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2020_3.zip',
             '/home/dsc/Downloads/On_Time_Reporting_Carrier_On_Time_Performance_1987_present_2020_4.zip']:
    zfile = ZipFile(name)
    csv = zfile.open(zfile.filelist[0])
    dfs.append(pd.read_csv(csv))
    csv.close()
    zfile.close()
# Out:
# /home/dsc/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (48,69,76,77,84) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)
# /home/dsc/anaconda3/lib/python3.7/site-packages/IPython/core/interactiveshell.py:3020: DtypeWarning: Columns (69,76,77,84) have mixed types.Specify dtype option on import or set low_memory=False.
#   interactivity=interactivity, compiler=compiler, result=result)

# %%
flights = pd.concat(dfs)

# %%
flights.shape
# Out:
# (961611, 110)

# %%
flights.iloc[:0]
# Out:
# Empty DataFrame
# Columns: [Year, Quarter, Month, DayofMonth, DayOfWeek, FlightDate, Reporting_Airline, DOT_ID_Reporting_Airline, IATA_CODE_Reporting_Airline, Tail_Number, Flight_Number_Reporting_Airline, OriginAirportID, OriginAirportSeqID, OriginCityMarketID, Origin, OriginCityName, OriginState, OriginStateFips, OriginStateName, OriginWac, DestAirportID, DestAirportSeqID, DestCityMarketID, Dest, DestCityName, DestState, DestStateFips, DestStateName, DestWac, CRSDepTime, DepTime, DepDelay, DepDelayMinutes, DepDel15, DepartureDelayGroups, DepTimeBlk, TaxiOut, WheelsOff, WheelsOn, TaxiIn, CRSArrTime, ArrTime, ArrDelay, ArrDelayMinutes, ArrDel15, ArrivalDelayGroups, ArrTimeBlk, Cancelled, CancellationCode, Diverted, CRSElapsedTime, ActualElapsedTime, AirTime, Flights, Distance, DistanceGroup, CarrierDelay, WeatherDelay, NASDelay, SecurityDelay, LateAircraftDelay, FirstDepTime, TotalAddGTime, LongestAddGTime, DivAirportLandings, DivReachedDest, DivActualElapsedTime, DivArrDelay, DivDistance, Div1Airport, Div1AirportID, Div1AirportSeqID, Div1WheelsOn, Div1TotalGTime, Div1LongestGTime, Div1WheelsOff, Div1TailNum, Div2Airport, Div2AirportID, Div2AirportSeqID, Div2WheelsOn, Div2TotalGTime, Div2LongestGTime, Div2WheelsOff, Div2TailNum, Div3Airport, Div3AirportID, Div3AirportSeqID, Div3WheelsOn, Div3TotalGTime, Div3LongestGTime, Div3WheelsOff, Div3TailNum, Div4Airport, Div4AirportID, Div4AirportSeqID, Div4WheelsOn, Div4TotalGTime, Div4LongestGTime, Div4WheelsOff, ...]
# Index: []

# %% [markdown]
# Be careful when reassigning variables to reserved words or functions.
# Do not flight.mean = something.

# %%
flights.mean
# Out:
# <bound method DataFrame.mean of         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 0       2020        1      3           9          1  2020-03-09
# 1       2020        1      3           9          1  2020-03-09
# 2       2020        1      3           7          6  2020-03-07
# 3       2020        1      3           7          6  2020-03-07
# 4       2020        1      3           7          6  2020-03-07
# ...      ...      ...    ...         ...        ...         ...
# 313377  2020        2      4           1          3  2020-04-01
# 313378  2020        2      4           1          3  2020-04-01
# 313379  2020        2      4           1          3  2020-04-01
# 313380  2020        2      4           1          3  2020-04-01
# 313381  2020        2      4           1          3  2020-04-01
#
#        Reporting_Airline  DOT_ID_Reporting_Airline  \
# 0                     9E                     20363
# 1                     9E                     20363
# 2                     9E                     20363
# 3                     9E                     20363
# 4                     9E                     20363
# ...                  ...                       ...
# 313377                YX                     20452
# 313378                YX                     20452
# 313379                YX                     20452
# 313380                YX                     20452
# 313381                YX                     20452
#
#        IATA_CODE_Reporting_Airline Tail_Number  \
# 0                               9E      N669CA
# 1                               9E      N669CA
# 2                               9E      N980EV
# 3                               9E      N980EV
# 4                               9E      N836AY
# ...                            ...         ...
# 313377                          YX      N648RW
# 313378                          YX      N645RW
# 313379                          YX      N725YX
# 313380                          YX      N730YX
# 313381                          YX      N861RW
#
#         Flight_Number_Reporting_Airline  OriginAirportID  OriginAirportSeqID  \
# 0                                  4677            11433             1143302
# 1                                  4677            14307             1430705
# 2                                  4678            11433             1143302
# 3                                  4678            15380             1538005
# 4                                  4680            10469             1046902
# ...                                 ...              ...                 ...
# 313377                             3404            11057             1105703
# 313378                             3403            11042             1104205
# 313379                             3402            10792             1079206
# 313380                             3401            12206             1220605
# 313381                             3400            11278             1127805
#
#         OriginCityMarketID Origin            OriginCityName OriginState  \
# 0                    31295    DTW               Detroit, MI          MI
# 1                    30721    PVD            Providence, RI          RI
# 2                    31295    DTW               Detroit, MI          MI
# 3                    35380    TVC         Traverse City, MI          MI
# 4                    30469    AZO             Kalamazoo, MI          MI
# ...                    ...    ...                       ...         ...
# 313377               31057    CLT             Charlotte, NC          NC
# 313378               30647    CLE             Cleveland, OH          OH
# 313379               30792    BUF               Buffalo, NY          NY
# 313380               32206    HRL  Harlingen/San Benito, TX          TX
# 313381               30852    DCA            Washington, DC          VA
#
#         OriginStateFips OriginStateName  OriginWac  DestAirportID  \
# 0                    26        Michigan         43          14307
# 1                    44    Rhode Island         15          11433
# 2                    26        Michigan         43          15380
# 3                    26        Michigan         43          11433
# 4                    26        Michigan         43          11433
# ...                 ...             ...        ...            ...
# 313377               37  North Carolina         36          11292
# 313378               39            Ohio         44          11618
# 313379               36        New York         22          11618
# 313380               48           Texas         74          12266
# 313381               51        Virginia         38          13930
#
#         DestAirportSeqID  DestCityMarketID Dest       DestCityName DestState  \
# 0                1430705             30721  PVD     Providence, RI        RI
# 1                1143302             31295  DTW        Detroit, MI        MI
# 2                1538005             35380  TVC  Traverse City, MI        MI
# 3                1143302             31295  DTW        Detroit, MI        MI
# 4                1143302             31295  DTW        Detroit, MI        MI
# ...                  ...               ...  ...                ...       ...
# 313377           1129202             30325  DEN         Denver, CO        CO
# 313378           1161802             31703  EWR         Newark, NJ        NJ
# 313379           1161802             31703  EWR         Newark, NJ        NJ
# 313380           1226603             31453  IAH        Houston, TX        TX
# 313381           1393007             30977  ORD        Chicago, IL        IL
#
#         DestStateFips DestStateName  DestWac  CRSDepTime  DepTime  DepDelay  \
# 0                  44  Rhode Island       15        1423   1412.0     -11.0
# 1                  26      Michigan       43        1650   1646.0      -4.0
# 2                  26      Michigan       43        1544   1539.0      -5.0
# 3                  26      Michigan       43        1759   1743.0     -16.0
# 4                  26      Michigan       43        1349   1344.0      -5.0
# ...               ...           ...      ...         ...      ...       ...
# 313377              8      Colorado       82        1645      NaN       NaN
# 313378             34    New Jersey       21        1700   1652.0      -8.0
# 313379             34    New Jersey       21         700    933.0     153.0
# 313380             48         Texas       74         730    720.0     -10.0
# 313381             17      Illinois       41         845    837.0      -8.0
#
#         DepDelayMinutes  DepDel15  DepartureDelayGroups DepTimeBlk  TaxiOut  \
# 0                   0.0       0.0                  -1.0  1400-1459     16.0
# 1                   0.0       0.0                  -1.0  1600-1659     18.0
# 2                   0.0       0.0                  -1.0  1500-1559     12.0
# 3                   0.0       0.0                  -2.0  1700-1759     11.0
# 4                   0.0       0.0                  -1.0  1300-1359      7.0
# ...                 ...       ...                   ...        ...      ...
# 313377              NaN       NaN                   NaN  1600-1659      NaN
# 313378              0.0       0.0                  -1.0  1700-1759     13.0
# 313379            153.0       1.0                  10.0  0700-0759      8.0
# 313380              0.0       0.0                  -1.0  0700-0759     11.0
# 313381              0.0       0.0                  -1.0  0800-0859     10.0
#
#         WheelsOff  WheelsOn  TaxiIn  CRSArrTime  ArrTime  ArrDelay  \
# 0          1428.0    1552.0     5.0        1615   1557.0     -18.0
# 1          1704.0    1846.0     7.0        1909   1853.0     -16.0
# 2          1551.0    1633.0     3.0        1658   1636.0     -22.0
# 3          1754.0    1829.0    10.0        1921   1839.0     -42.0
# 4          1351.0    1421.0     8.0        1454   1429.0     -25.0
# ...           ...       ...     ...         ...      ...       ...
# 313377        NaN       NaN     NaN        1840      NaN       NaN
# 313378     1705.0    1806.0     6.0        1847   1812.0     -35.0
# 313379      941.0    1036.0     4.0         828   1040.0     132.0
# 313380      731.0     823.0     8.0         848    831.0     -17.0
# 313381      847.0     923.0     7.0         957    930.0     -27.0
#
#         ArrDelayMinutes  ArrDel15  ArrivalDelayGroups ArrTimeBlk  Cancelled  \
# 0                   0.0       0.0                -2.0  1600-1659        0.0
# 1                   0.0       0.0                -2.0  1900-1959        0.0
# 2                   0.0       0.0                -2.0  1600-1659        0.0
# 3                   0.0       0.0                -2.0  1900-1959        0.0
# 4                   0.0       0.0                -2.0  1400-1459        0.0
# ...                 ...       ...                 ...        ...        ...
# 313377              NaN       NaN                 NaN  1800-1859        1.0
# 313378              0.0       0.0                -2.0  1800-1859        0.0
# 313379            132.0       1.0                 8.0  0800-0859        0.0
# 313380              0.0       0.0                -2.0  0800-0859        0.0
# 313381              0.0       0.0                -2.0  0900-0959        0.0
#
#        CancellationCode  Diverted  CRSElapsedTime  ActualElapsedTime  AirTime  \
# 0                   NaN       0.0           112.0              105.0     84.0
# 1                   NaN       0.0           139.0              127.0    102.0
# 2                   NaN       0.0            74.0               57.0     42.0
# 3                   NaN       0.0            82.0               56.0     35.0
# 4                   NaN       0.0            65.0               45.0     30.0
# ...                 ...       ...             ...                ...      ...
# 313377                D       0.0           235.0                NaN      NaN
# 313378              NaN       0.0           107.0               80.0     61.0
# 313379              NaN       0.0            88.0               67.0     55.0
# 313380              NaN       0.0            78.0               71.0     52.0
# 313381              NaN       0.0           132.0              113.0     96.0
#
#         Flights  Distance  DistanceGroup  CarrierDelay  WeatherDelay  \
# 0           1.0     615.0              3           NaN           NaN
# 1           1.0     615.0              3           NaN           NaN
# 2           1.0     207.0              1           NaN           NaN
# 3           1.0     207.0              1           NaN           NaN
# 4           1.0     113.0              1           NaN           NaN
# ...         ...       ...            ...           ...           ...
# 313377      1.0    1337.0              6           NaN           NaN
# 313378      1.0     404.0              2           NaN           NaN
# 313379      1.0     282.0              2         132.0           0.0
# 313380      1.0     295.0              2           NaN           NaN
# 313381      1.0     612.0              3           NaN           NaN
#
#         NASDelay  SecurityDelay  LateAircraftDelay  FirstDepTime  \
# 0            NaN            NaN                NaN           NaN
# 1            NaN            NaN                NaN           NaN
# 2            NaN            NaN                NaN           NaN
# 3            NaN            NaN                NaN           NaN
# 4            NaN            NaN                NaN           NaN
# ...          ...            ...                ...           ...
# 313377       NaN            NaN                NaN           NaN
# 313378       NaN            NaN                NaN           NaN
# 313379       0.0            0.0                0.0           NaN
# 313380       NaN            NaN                NaN           NaN
# 313381       NaN            NaN                NaN           NaN
#
#         TotalAddGTime  LongestAddGTime  DivAirportLandings  DivReachedDest  \
# 0                 NaN              NaN                 0.0             NaN
# 1                 NaN              NaN                 0.0             NaN
# 2                 NaN              NaN                 0.0             NaN
# 3                 NaN              NaN                 0.0             NaN
# 4                 NaN              NaN                 0.0             NaN
# ...               ...              ...                 ...             ...
# 313377            NaN              NaN                 0.0             NaN
# 313378            NaN              NaN                 0.0             NaN
# 313379            NaN              NaN                 0.0             NaN
# 313380            NaN              NaN                 0.0             NaN
# 313381            NaN              NaN                 0.0             NaN
#
#         DivActualElapsedTime  DivArrDelay  DivDistance Div1Airport  \
# 0                        NaN          NaN          NaN         NaN
# 1                        NaN          NaN          NaN         NaN
# 2                        NaN          NaN          NaN         NaN
# 3                        NaN          NaN          NaN         NaN
# 4                        NaN          NaN          NaN         NaN
# ...                      ...          ...          ...         ...
# 313377                   NaN          NaN          NaN         NaN
# 313378                   NaN          NaN          NaN         NaN
# 313379                   NaN          NaN          NaN         NaN
# 313380                   NaN          NaN          NaN         NaN
# 313381                   NaN          NaN          NaN         NaN
#
#         Div1AirportID  Div1AirportSeqID  Div1WheelsOn  Div1TotalGTime  \
# 0                 NaN               NaN           NaN             NaN
# 1                 NaN               NaN           NaN             NaN
# 2                 NaN               NaN           NaN             NaN
# 3                 NaN               NaN           NaN             NaN
# 4                 NaN               NaN           NaN             NaN
# ...               ...               ...           ...             ...
# 313377            NaN               NaN           NaN             NaN
# 313378            NaN               NaN           NaN             NaN
# 313379            NaN               NaN           NaN             NaN
# 313380            NaN               NaN           NaN             NaN
# 313381            NaN               NaN           NaN             NaN
#
#         Div1LongestGTime  Div1WheelsOff Div1TailNum Div2Airport  \
# 0                    NaN            NaN         NaN         NaN
# 1                    NaN            NaN         NaN         NaN
# 2                    NaN            NaN         NaN         NaN
# 3                    NaN            NaN         NaN         NaN
# 4                    NaN            NaN         NaN         NaN
# ...                  ...            ...         ...         ...
# 313377               NaN            NaN         NaN         NaN
# 313378               NaN            NaN         NaN         NaN
# 313379               NaN            NaN         NaN         NaN
# 313380               NaN            NaN         NaN         NaN
# 313381               NaN            NaN         NaN         NaN
#
#         Div2AirportID  Div2AirportSeqID  Div2WheelsOn  Div2TotalGTime  \
# 0                 NaN               NaN           NaN             NaN
# 1                 NaN               NaN           NaN             NaN
# 2                 NaN               NaN           NaN             NaN
# 3                 NaN               NaN           NaN             NaN
# 4                 NaN               NaN           NaN             NaN
# ...               ...               ...           ...             ...
# 313377            NaN               NaN           NaN             NaN
# 313378            NaN               NaN           NaN             NaN
# 313379            NaN               NaN           NaN             NaN
# 313380            NaN               NaN           NaN             NaN
# 313381            NaN               NaN           NaN             NaN
#
#         Div2LongestGTime  Div2WheelsOff Div2TailNum  Div3Airport  \
# 0                    NaN            NaN         NaN          NaN
# 1                    NaN            NaN         NaN          NaN
# 2                    NaN            NaN         NaN          NaN
# 3                    NaN            NaN         NaN          NaN
# 4                    NaN            NaN         NaN          NaN
# ...                  ...            ...         ...          ...
# 313377               NaN            NaN         NaN          NaN
# 313378               NaN            NaN         NaN          NaN
# 313379               NaN            NaN         NaN          NaN
# 313380               NaN            NaN         NaN          NaN
# 313381               NaN            NaN         NaN          NaN
#
#         Div3AirportID  Div3AirportSeqID  Div3WheelsOn  Div3TotalGTime  \
# 0                 NaN               NaN           NaN             NaN
# 1                 NaN               NaN           NaN             NaN
# 2                 NaN               NaN           NaN             NaN
# 3                 NaN               NaN           NaN             NaN
# 4                 NaN               NaN           NaN             NaN
# ...               ...               ...           ...             ...
# 313377            NaN               NaN           NaN             NaN
# 313378            NaN               NaN           NaN             NaN
# 313379            NaN               NaN           NaN             NaN
# 313380            NaN               NaN           NaN             NaN
# 313381            NaN               NaN           NaN             NaN
#
#         Div3LongestGTime  Div3WheelsOff  Div3TailNum  Div4Airport  \
# 0                    NaN            NaN          NaN          NaN
# 1                    NaN            NaN          NaN          NaN
# 2                    NaN            NaN          NaN          NaN
# 3                    NaN            NaN          NaN          NaN
# 4                    NaN            NaN          NaN          NaN
# ...                  ...            ...          ...          ...
# 313377               NaN            NaN          NaN          NaN
# 313378               NaN            NaN          NaN          NaN
# 313379               NaN            NaN          NaN          NaN
# 313380               NaN            NaN          NaN          NaN
# 313381               NaN            NaN          NaN          NaN
#
#         Div4AirportID  Div4AirportSeqID  Div4WheelsOn  Div4TotalGTime  \
# 0                 NaN               NaN           NaN             NaN
# 1                 NaN               NaN           NaN             NaN
# 2                 NaN               NaN           NaN             NaN
# 3                 NaN               NaN           NaN             NaN
# 4                 NaN               NaN           NaN             NaN
# ...               ...               ...           ...             ...
# 313377            NaN               NaN           NaN             NaN
# 313378            NaN               NaN           NaN             NaN
# 313379            NaN               NaN           NaN             NaN
# 313380            NaN               NaN           NaN             NaN
# 313381            NaN               NaN           NaN             NaN
#
#         Div4LongestGTime  Div4WheelsOff  Div4TailNum  Div5Airport  \
# 0                    NaN            NaN          NaN          NaN
# 1                    NaN            NaN          NaN          NaN
# 2                    NaN            NaN          NaN          NaN
# 3                    NaN            NaN          NaN          NaN
# 4                    NaN            NaN          NaN          NaN
# ...                  ...            ...          ...          ...
# 313377               NaN            NaN          NaN          NaN
# 313378               NaN            NaN          NaN          NaN
# 313379               NaN            NaN          NaN          NaN
# 313380               NaN            NaN          NaN          NaN
# 313381               NaN            NaN          NaN          NaN
#
#         Div5AirportID  Div5AirportSeqID  Div5WheelsOn  Div5TotalGTime  \
# 0                 NaN               NaN           NaN             NaN
# 1                 NaN               NaN           NaN             NaN
# 2                 NaN               NaN           NaN             NaN
# 3                 NaN               NaN           NaN             NaN
# 4                 NaN               NaN           NaN             NaN
# ...               ...               ...           ...             ...
# 313377            NaN               NaN           NaN             NaN
# 313378            NaN               NaN           NaN             NaN
# 313379            NaN               NaN           NaN             NaN
# 313380            NaN               NaN           NaN             NaN
# 313381            NaN               NaN           NaN             NaN
#
#         Div5LongestGTime  Div5WheelsOff  Div5TailNum  Unnamed: 109
# 0                    NaN            NaN          NaN           NaN
# 1                    NaN            NaN          NaN           NaN
# 2                    NaN            NaN          NaN           NaN
# 3                    NaN            NaN          NaN           NaN
# 4                    NaN            NaN          NaN           NaN
# ...                  ...            ...          ...           ...
# 313377               NaN            NaN          NaN           NaN
# 313378               NaN            NaN          NaN           NaN
# 313379               NaN            NaN          NaN           NaN
# 313380               NaN            NaN          NaN           NaN
# 313381               NaN            NaN          NaN           NaN
#
# [961611 rows x 110 columns]>

# %% [markdown]
# # Data Transformation

# %% [markdown]
# ## Removing Duplicates

# %%
left
# Out:
#    data1 key
# 0    158   b
# 1    147   a
# 2    120   c
# 3    158   b
# 4    135   a
# 5    189   a
# 6    140   c
# 7    180   b

# %%
left.drop_duplicates(subset = ['key'], keep = 'last')
# Out:
#    data1 key
# 5    189   a
# 6    140   c
# 7    180   b

# %% [markdown]
# __Exercise__

# %% [markdown]
# How many individual airports are there?

# %%
pd.options.display.max_columns = None
flights.sample(5)
# Out:
#         Year  Quarter  Month  DayofMonth  DayOfWeek  FlightDate  \
# 383228  2020        1      3          29          7  2020-03-29
# 25007   2020        1      3          22          7  2020-03-22
# 497481  2020        1      3          17          2  2020-03-17
# 5737    2020        1      3          18          3  2020-03-18
# 183991  2020        1      3           6          5  2020-03-06
#
#        Reporting_Airline  DOT_ID_Reporting_Airline  \
# 383228                WN                     19393
# 25007                 9E                     20363
# 497481                OH                     20397
# 5737                  9E                     20363
# 183991                DL                     19790
#
#        IATA_CODE_Reporting_Airline Tail_Number  \
# 383228                          WN      N950WN
# 25007                           9E      N391CA
# 497481                          OH      N558NN
# 5737                            9E      N916XJ
# 183991                          DL      N311DN
#
#         Flight_Number_Reporting_Airline  OriginAirportID  OriginAirportSeqID  \
# 383228                             4998            11292             1129202
# 25007                              5396            13487             1348702
# 497481                             5084            11057             1105703
# 5737                               4887            12884             1288403
# 183991                              833            14679             1467903
#
#         OriginCityMarketID Origin   OriginCityName OriginState  \
# 383228               30325    DEN       Denver, CO          CO
# 25007                31650    MSP  Minneapolis, MN          MN
# 497481               31057    CLT    Charlotte, NC          NC
# 5737                 32884    LAN      Lansing, MI          MI
# 183991               33570    SAN    San Diego, CA          CA
#
#         OriginStateFips OriginStateName  OriginWac  DestAirportID  \
# 383228                8        Colorado         82          14107
# 25007                27       Minnesota         63          14524
# 497481               37  North Carolina         36          15412
# 5737                 26        Michigan         43          11433
# 183991                6      California         91          11433
#
#         DestAirportSeqID  DestCityMarketID Dest   DestCityName DestState  \
# 383228           1410702             30466  PHX    Phoenix, AZ        AZ
# 25007            1452401             34524  RIC   Richmond, VA        VA
# 497481           1541205             35412  TYS  Knoxville, TN        TN
# 5737             1143302             31295  DTW    Detroit, MI        MI
# 183991           1143302             31295  DTW    Detroit, MI        MI
#
#         DestStateFips DestStateName  DestWac  CRSDepTime  DepTime  DepDelay  \
# 383228              4       Arizona       81        2005   2001.0      -4.0
# 25007              51      Virginia       38        1247   1243.0      -4.0
# 497481             47     Tennessee       54         930    917.0     -13.0
# 5737               26      Michigan       43         515    506.0      -9.0
# 183991             26      Michigan       43        1205   1204.0      -1.0
#
#         DepDelayMinutes  DepDel15  DepartureDelayGroups DepTimeBlk  TaxiOut  \
# 383228              0.0       0.0                  -1.0  2000-2059      8.0
# 25007               0.0       0.0                  -1.0  1200-1259     13.0
# 497481              0.0       0.0                  -1.0  0900-0959     24.0
# 5737                0.0       0.0                  -1.0  0001-0559     13.0
# 183991              0.0       0.0                  -1.0  1200-1259     22.0
#
#         WheelsOff  WheelsOn  TaxiIn  CRSArrTime  ArrTime  ArrDelay  \
# 383228     2009.0    2046.0     9.0        2100   2055.0      -5.0
# 25007      1256.0    1606.0     5.0        1621   1611.0     -10.0
# 497481      941.0    1019.0     3.0        1040   1022.0     -18.0
# 5737        519.0     543.0     9.0         620    552.0     -28.0
# 183991     1226.0    1921.0    10.0        1928   1931.0       3.0
#
#         ArrDelayMinutes  ArrDel15  ArrivalDelayGroups ArrTimeBlk  Cancelled  \
# 383228              0.0       0.0                -1.0  2100-2159        0.0
# 25007               0.0       0.0                -1.0  1600-1659        0.0
# 497481              0.0       0.0                -2.0  1000-1059        0.0
# 5737                0.0       0.0                -2.0  0600-0659        0.0
# 183991              3.0       0.0                 0.0  1900-1959        0.0
#
#        CancellationCode  Diverted  CRSElapsedTime  ActualElapsedTime  AirTime  \
# 383228              NaN       0.0           115.0              114.0     97.0
# 25007               NaN       0.0           154.0              148.0    130.0
# 497481              NaN       0.0            70.0               65.0     38.0
# 5737                NaN       0.0            65.0               46.0     24.0
# 183991              NaN       0.0           263.0              267.0    235.0
#
#         Flights  Distance  DistanceGroup  CarrierDelay  WeatherDelay  \
# 383228      1.0     602.0              3           NaN           NaN
# 25007       1.0     970.0              4           NaN           NaN
# 497481      1.0     177.0              1           NaN           NaN
# 5737        1.0      74.0              1           NaN           NaN
# 183991      1.0    1956.0              8           NaN           NaN
#
#         NASDelay  SecurityDelay  LateAircraftDelay  FirstDepTime  \
# 383228       NaN            NaN                NaN           NaN
# 25007        NaN            NaN                NaN           NaN
# 497481       NaN            NaN                NaN           NaN
# 5737         NaN            NaN                NaN           NaN
# 183991       NaN            NaN                NaN           NaN
#
#         TotalAddGTime  LongestAddGTime  DivAirportLandings  DivReachedDest  \
# 383228            NaN              NaN                 0.0             NaN
# 25007             NaN              NaN                 0.0             NaN
# 497481            NaN              NaN                 0.0             NaN
# 5737              NaN              NaN                 0.0             NaN
# 183991            NaN              NaN                 0.0             NaN
#
#         DivActualElapsedTime  DivArrDelay  DivDistance Div1Airport  \
# 383228                   NaN          NaN          NaN         NaN
# 25007                    NaN          NaN          NaN         NaN
# 497481                   NaN          NaN          NaN         NaN
# 5737                     NaN          NaN          NaN         NaN
# 183991                   NaN          NaN          NaN         NaN
#
#         Div1AirportID  Div1AirportSeqID  Div1WheelsOn  Div1TotalGTime  \
# 383228            NaN               NaN           NaN             NaN
# 25007             NaN               NaN           NaN             NaN
# 497481            NaN               NaN           NaN             NaN
# 5737              NaN               NaN           NaN             NaN
# 183991            NaN               NaN           NaN             NaN
#
#         Div1LongestGTime  Div1WheelsOff Div1TailNum Div2Airport  \
# 383228               NaN            NaN         NaN         NaN
# 25007                NaN            NaN         NaN         NaN
# 497481               NaN            NaN         NaN         NaN
# 5737                 NaN            NaN         NaN         NaN
# 183991               NaN            NaN         NaN         NaN
#
#         Div2AirportID  Div2AirportSeqID  Div2WheelsOn  Div2TotalGTime  \
# 383228            NaN               NaN           NaN             NaN
# 25007             NaN               NaN           NaN             NaN
# 497481            NaN               NaN           NaN             NaN
# 5737              NaN               NaN           NaN             NaN
# 183991            NaN               NaN           NaN             NaN
#
#         Div2LongestGTime  Div2WheelsOff Div2TailNum  Div3Airport  \
# 383228               NaN            NaN         NaN          NaN
# 25007                NaN            NaN         NaN          NaN
# 497481               NaN            NaN         NaN          NaN
# 5737                 NaN            NaN         NaN          NaN
# 183991               NaN            NaN         NaN          NaN
#
#         Div3AirportID  Div3AirportSeqID  Div3WheelsOn  Div3TotalGTime  \
# 383228            NaN               NaN           NaN             NaN
# 25007             NaN               NaN           NaN             NaN
# 497481            NaN               NaN           NaN             NaN
# 5737              NaN               NaN           NaN             NaN
# 183991            NaN               NaN           NaN             NaN
#
#         Div3LongestGTime  Div3WheelsOff  Div3TailNum  Div4Airport  \
# 383228               NaN            NaN          NaN          NaN
# 25007                NaN            NaN          NaN          NaN
# 497481               NaN            NaN          NaN          NaN
# 5737                 NaN            NaN          NaN          NaN
# 183991               NaN            NaN          NaN          NaN
#
#         Div4AirportID  Div4AirportSeqID  Div4WheelsOn  Div4TotalGTime  \
# 383228            NaN               NaN           NaN             NaN
# 25007             NaN               NaN           NaN             NaN
# 497481            NaN               NaN           NaN             NaN
# 5737              NaN               NaN           NaN             NaN
# 183991            NaN               NaN           NaN             NaN
#
#         Div4LongestGTime  Div4WheelsOff  Div4TailNum  Div5Airport  \
# 383228               NaN            NaN          NaN          NaN
# 25007                NaN            NaN          NaN          NaN
# 497481               NaN            NaN          NaN          NaN
# 5737                 NaN            NaN          NaN          NaN
# 183991               NaN            NaN          NaN          NaN
#
#         Div5AirportID  Div5AirportSeqID  Div5WheelsOn  Div5TotalGTime  \
# 383228            NaN               NaN           NaN             NaN
# 25007             NaN               NaN           NaN             NaN
# 497481            NaN               NaN           NaN             NaN
# 5737              NaN               NaN           NaN             NaN
# 183991            NaN               NaN           NaN             NaN
#
#         Div5LongestGTime  Div5WheelsOff  Div5TailNum  Unnamed: 109
# 383228               NaN            NaN          NaN           NaN
# 25007                NaN            NaN          NaN           NaN
# 497481               NaN            NaN          NaN           NaN
# 5737                 NaN            NaN          NaN           NaN
# 183991               NaN            NaN          NaN           NaN

# %%
flights['Origin'].nunique()
# Out:
# 353

# %%
flights.drop_duplicates(subset = 'Origin').shape
# Out:
# (353, 110)

# %% [markdown]
# How many routes (combinations of origin / destination)?

# %%
flights.drop_duplicates(subset = ['Origin', 'Dest']).shape
# Out:
# (5844, 110)

# %%
(flights['Origin'] + '-' + flights['Dest']).nunique()
# Out:
# 5844

# %% [markdown]
# ## Renaming axis indexes

# %%
left.index = list('abcdefgh')
left
# Out:
#    data1 key
# a    158   b
# b    147   a
# c    120   c
# d    158   b
# e    135   a
# f    189   a
# g    140   c
# h    180   b

# %%
left.index
# Out:
# Index(['a', 'b', 'c', 'd', 'e', 'f', 'g', 'h'], dtype='object')

# %% [markdown]
# ## Discretization and binning

# %%
incognito = pd.cut(flights['Distance'], range(100, 2000, 500))
incognito
# Out:
# 0          (600, 1100]
# 1          (600, 1100]
# 2           (100, 600]
# 3           (100, 600]
# 4           (100, 600]
#               ...
# 313377    (1100, 1600]
# 313378      (100, 600]
# 313379      (100, 600]
# 313380      (100, 600]
# 313381     (600, 1100]
# Name: Distance, Length: 961611, dtype: category
# Categories (3, interval[int64]): [(100, 600] < (600, 1100] < (1100, 1600]]

# %%
incognito = pd.cut(flights['Distance'], 10)
incognito
# Out:
# 0          (537.4, 1043.8]
# 1          (537.4, 1043.8]
# 2          (25.936, 537.4]
# 3          (25.936, 537.4]
# 4          (25.936, 537.4]
#                 ...
# 313377    (1043.8, 1550.2]
# 313378     (25.936, 537.4]
# 313379     (25.936, 537.4]
# 313380     (25.936, 537.4]
# 313381     (537.4, 1043.8]
# Name: Distance, Length: 961611, dtype: category
# Categories (10, interval[float64]): [(25.936, 537.4] < (537.4, 1043.8] < (1043.8, 1550.2] < (1550.2, 2056.6] ... (3069.4, 3575.8] < (3575.8, 4082.2] < (4082.2, 4588.6] < (4588.6, 5095.0]]

# %%
incognito.value_counts()
# Out:
# (25.936, 537.4]     390299
# (537.4, 1043.8]     341401
# (1043.8, 1550.2]    136322
# (1550.2, 2056.6]     48376
# (2056.6, 2563.0]     35064
# (2563.0, 3069.4]      8898
# (3575.8, 4082.2]       570
# (3069.4, 3575.8]       249
# (4082.2, 4588.6]       230
# (4588.6, 5095.0]       202
# Name: Distance, dtype: int64

# %%
ages = np.random.randint(0, 99, size = 25)
pd.cut(ages, [0, 2, 12, 19, 35, 65, 100]).value_counts()
# Out:
# (0, 2]        0
# (2, 12]       0
# (12, 19]      2
# (19, 35]      3
# (35, 65]      8
# (65, 100]    12
# dtype: int64

# %% [markdown]
# ## String manipulation

# %% [markdown]
# ### String object methods

# %%
animals = pd.Series('fairy goblin orc elf mamoth narwhal'.split())
animals
# Out:
# 0      fairy
# 1     goblin
# 2        orc
# 3        elf
# 4     mamoth
# 5    narwhal
# dtype: object

# %%
animals.str.len()
# Out:
# 0    5
# 1    6
# 2    3
# 3    3
# 4    6
# 5    7
# dtype: int64

# %%
animals.str.capitalize()
# Out:
# 0      Fairy
# 1     Goblin
# 2        Orc
# 3        Elf
# 4     Mamoth
# 5    Narwhal
# dtype: object

# %%
animals.str.upper()
# Out:
# 0      FAIRY
# 1     GOBLIN
# 2        ORC
# 3        ELF
# 4     MAMOTH
# 5    NARWHAL
# dtype: object

# %%
animals.str[0]
# Out:
# 0    f
# 1    g
# 2    o
# 3    e
# 4    m
# 5    n
# dtype: object

# %% [markdown]
# ### Vectorized string functions in Pandas

# %% [markdown]
# There are two ways to store text data in Pandas:
#
# - 1. object -dtype Numpy array
# - 2. StringDtype extension type (this is the case)
#
# The string attributes have the same names as the regular Python string functions, but work on Series of strings.

# %% [markdown]
# __Exercise__

# %% [markdown]
# Generate a list of the columns that have 'Origin' in their name

# %%
flights.columns[flights.columns.str.contains('Origin')]
# Out:
# Index(['OriginAirportID', 'OriginAirportSeqID', 'OriginCityMarketID', 'Origin',
#        'OriginCityName', 'OriginState', 'OriginStateFips', 'OriginStateName',
#        'OriginWac'],
#       dtype='object')

# %%
flights[flights.columns[flights.columns.str.contains('Origin')]].sample(5)
# Out:
#         OriginAirportID  OriginAirportSeqID  OriginCityMarketID Origin  \
# 120967            13873             1387305               33873    OME
# 492409            13930             1393007               30977    ORD
# 641892            11292             1129202               30325    DEN
# 452300            11481             1148102               31481    ECP
# 7925              11298             1129806               30194    DFW
#
#                OriginCityName OriginState  OriginStateFips OriginStateName  \
# 120967               Nome, AK          AK                2          Alaska
# 492409            Chicago, IL          IL               17        Illinois
# 641892             Denver, CO          CO                8        Colorado
# 452300        Panama City, FL          FL               12         Florida
# 7925    Dallas/Fort Worth, TX          TX               48           Texas
#
#         OriginWac
# 120967          1
# 492409         41
# 641892         82
# 452300         33
# 7925           74

# %% [markdown]
# If we filter the interesting columns we want

# %%
interesting_columns= ['FlightDate', 'DayOfWeek', 'Reporting_Airline', 'Tail_Number', 'Flight_Number_Reporting_Airline', 
                      'Origin', 'OriginCityName', 'OriginStateName', 'OriginCityMarketID',
                      'Dest', 'DestCityName', 'DestStateName', 'DestCityMarketID',
                      'DepTime', 'DepDelay', 'AirTime', 'Distance']

flights = flights[interesting_columns]

# %%
flights.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 961611 entries, 0 to 313381
# Data columns (total 17 columns):
#  #   Column                           Non-Null Count   Dtype
# ---  ------                           --------------   -----
#  0   FlightDate                       961611 non-null  object
#  1   DayOfWeek                        961611 non-null  int64
#  2   Reporting_Airline                961611 non-null  object
#  3   Tail_Number                      822783 non-null  object
#  4   Flight_Number_Reporting_Airline  961611 non-null  int64
#  5   Origin                           961611 non-null  object
#  6   OriginCityName                   961611 non-null  object
#  7   OriginStateName                  961611 non-null  object
#  8   OriginCityMarketID               961611 non-null  int64
#  9   Dest                             961611 non-null  object
#  10  DestCityName                     961611 non-null  object
#  11  DestStateName                    961611 non-null  object
#  12  DestCityMarketID                 961611 non-null  int64
#  13  DepTime                          721658 non-null  float64
#  14  DepDelay                         721656 non-null  float64
#  15  AirTime                          720250 non-null  float64
#  16  Distance                         961611 non-null  float64
# dtypes: float64(4), int64(4), object(9)
# memory usage: 132.1+ MB

# %% [markdown]
# # Data Aggregation and Group Operations

# %% [markdown]
# ## GroupBy mechanics

# %%
left = pd.DataFrame({'data1' : np.random.randint(100, 200, 8), 'key' : list('bacbaacb')})
right = pd.DataFrame({'data2' : np.random.randint(10, 99, 7), 'key' : list('acaacdd')})
left
# Out:
#    data1 key
# 0    117   b
# 1    138   a
# 2    183   c
# 3    138   b
# 4    120   a
# 5    126   a
# 6    176   c
# 7    124   b

# %%
left.groupby('key')

# %%
left.groupby('key').count()
# Out:
#      data1
# key
# a        3
# b        3
# c        2

# %%
left.groupby('key').mean()
# Out:
#           data1
# key
# a    128.000000
# b    126.333333
# c    179.500000

# %%
flights.groupby('Origin').count()
# Out:
#         FlightDate  DayOfWeek  Reporting_Airline  Tail_Number  \
# Origin
# ABE            687        687                687          490
# ABI            317        317                317          287
# ABQ           3435       3435               3435         2788
# ABR            122        122                122          122
# ABY            139        139                139          139
# ...            ...        ...                ...          ...
# WRG            122        122                122          122
# XNA           1891       1891               1891         1636
# XWA            139        139                139          139
# YAK            122        122                122          122
# YUM            276        276                276          241
#
#         Flight_Number_Reporting_Airline  OriginCityName  OriginStateName  \
# Origin
# ABE                                 687             687              687
# ABI                                 317             317              317
# ABQ                                3435            3435             3435
# ABR                                 122             122              122
# ABY                                 139             139              139
# ...                                 ...             ...              ...
# WRG                                 122             122              122
# XNA                                1891            1891             1891
# XWA                                 139             139              139
# YAK                                 122             122              122
# YUM                                 276             276              276
#
#         OriginCityMarketID  Dest  DestCityName  DestStateName  \
# Origin
# ABE                    687   687           687            687
# ABI                    317   317           317            317
# ABQ                   3435  3435          3435           3435
# ABR                    122   122           122            122
# ABY                    139   139           139            139
# ...                    ...   ...           ...            ...
# WRG                    122   122           122            122
# XNA                   1891  1891          1891           1891
# XWA                    139   139           139            139
# YAK                    122   122           122            122
# YUM                    276   276           276            276
#
#         DestCityMarketID  DepTime  DepDelay  AirTime  Distance
# Origin
# ABE                  687      467       467      467       687
# ABI                  317      265       265      265       317
# ABQ                 3435     2483      2483     2481      3435
# ABR                  122      115       115      115       122
# ABY                  139      121       121      120       139
# ...                  ...      ...       ...      ...       ...
# WRG                  122      119       119      117       122
# XNA                 1891     1436      1436     1434      1891
# XWA                  139      124       124      124       139
# YAK                  122      115       115      115       122
# YUM                  276      217       217      217       276
#
# [353 rows x 16 columns]

# %%
flights['FlightDate'].str[-5:-3]
# Out:
# 0         03
# 1         03
# 2         03
# 3         03
# 4         03
#           ..
# 313377    04
# 313378    04
# 313379    04
# 313380    04
# 313381    04
# Name: FlightDate, Length: 961611, dtype: object

# %%
flights.groupby(flights['FlightDate'].str[-5:-3]).count()
# Out:
#             FlightDate  DayOfWeek  Reporting_Airline  Tail_Number  \
# FlightDate
# 03              648229     648229             648229       599908
# 04              313382     313382             313382       222875
#
#             Flight_Number_Reporting_Airline  Origin  OriginCityName  \
# FlightDate
# 03                                   648229  648229          648229
# 04                                   313382  313382          313382
#
#             OriginStateName  OriginCityMarketID    Dest  DestCityName  \
# FlightDate
# 03                   648229              648229  648229        648229
# 04                   313382              313382  313382        313382
#
#             DestStateName  DestCityMarketID  DepTime  DepDelay  AirTime  \
# FlightDate
# 03                 648229            648229   538275    538273   537244
# 04                 313382            313382   183383    183383   183006
#
#             Distance
# FlightDate
# 03            648229
# 04            313382

# %%
flights.groupby(['Origin', 'Dest']).count()
# Out:
#              FlightDate  DayOfWeek  Reporting_Airline  Tail_Number  \
# Origin Dest
# ABE    ATL           87         87                 87           74
#        BNA           15         15                 15            6
#        CLT          183        183                183          122
#        DTW          120        120                120          120
#        FLL           13         13                 13            6
# ...                 ...        ...                ...          ...
# XWA    MSP           92         92                 92           92
# YAK    CDV           61         61                 61           61
#        JNU           61         61                 61           61
# YUM    DFW           61         61                 61           61
#        PHX          215        215                215          180
#
#              Flight_Number_Reporting_Airline  OriginCityName  OriginStateName  \
# Origin Dest
# ABE    ATL                                87              87               87
#        BNA                                15              15               15
#        CLT                               183             183              183
#        DTW                               120             120              120
#        FLL                                13              13               13
# ...                                      ...             ...              ...
# XWA    MSP                                92              92               92
# YAK    CDV                                61              61               61
#        JNU                                61              61               61
# YUM    DFW                                61              61               61
#        PHX                               215             215              215
#
#              OriginCityMarketID  DestCityName  DestStateName  \
# Origin Dest
# ABE    ATL                   87            87             87
#        BNA                   15            15             15
#        CLT                  183           183            183
#        DTW                  120           120            120
#        FLL                   13            13             13
# ...                         ...           ...            ...
# XWA    MSP                   92            92             92
# YAK    CDV                   61            61             61
#        JNU                   61            61             61
# YUM    DFW                   61            61             61
#        PHX                  215           215            215
#
#              DestCityMarketID  DepTime  DepDelay  AirTime  Distance
# Origin Dest
# ABE    ATL                 87       61        61       61        87
#        BNA                 15        6         6        6        15
#        CLT                183      119       119      119       183
#        DTW                120      115       115      115       120
#        FLL                 13        6         6        6        13
# ...                       ...      ...       ...      ...       ...
# XWA    MSP                 92       90        90       90        92
# YAK    CDV                 61       58        58       58        61
#        JNU                 61       57        57       57        61
# YUM    DFW                 61       61        61       61        61
#        PHX                215      156       156      156       215
#
# [5844 rows x 15 columns]

# %% [markdown]
# ### Iterating over groups

# %%
for id_, group in left.groupby('key'):
    print(id_)
    print(group.shape)
# Out:
# a
# (3, 2)
# b
# (3, 2)
# c
# (2, 2)

# %% [markdown]
# ### Selecting a column or subset of columns

# %%
flights.groupby(['Origin', 'Dest'])['AirTime'].mean()
# Out:
# Origin  Dest
# ABE     ATL     106.163934
#         BNA     101.500000
#         CLT      89.436975
#         DTW      78.773913
#         FLL     139.833333
#                    ...
# XWA     MSP      75.955556
# YAK     CDV      38.172414
#         JNU      34.736842
# YUM     DFW     124.426230
#         PHX      32.012821
# Name: AirTime, Length: 5844, dtype: float64

# %% [markdown]
# ## Data Agreggation

# %%
flights.groupby(['Origin', 'Dest'])['AirTime'].agg(['mean', 'std'])
# Out:
#                    mean       std
# Origin Dest
# ABE    ATL   106.163934  7.842577
#        BNA   101.500000  3.146427
#        CLT    89.436975  8.872581
#        DTW    78.773913  7.449315
#        FLL   139.833333  9.196014
# ...                 ...       ...
# XWA    MSP    75.955556  3.842141
# YAK    CDV    38.172414  1.974735
#        JNU    34.736842  3.073657
# YUM    DFW   124.426230  7.161143
#        PHX    32.012821  3.452885
#
# [5844 rows x 2 columns]

# %% [markdown]
# ### Columns-wise and multiple function application

# %%
groupby = flights.groupby(['Origin', 'Dest'])['AirTime']
groupby.agg(lambda series: series.max() - series.min())
# Out:
# Origin  Dest
# ABE     ATL     39.0
#         BNA      9.0
#         CLT     45.0
#         DTW     36.0
#         FLL     27.0
#                 ...
# XWA     MSP     20.0
# YAK     CDV     10.0
#         JNU     22.0
# YUM     DFW     28.0
#         PHX     24.0
# Name: AirTime, Length: 5844, dtype: float64

# %%
time_route = flights.groupby(['Origin', 'Dest']).agg({'AirTime': ['mean', 'std'], 'Distance': 'min'})
time_route
# Out:
#                 AirTime           Distance
#                    mean       std      min
# Origin Dest
# ABE    ATL   106.163934  7.842577    692.0
#        BNA   101.500000  3.146427    685.0
#        CLT    89.436975  8.872581    481.0
#        DTW    78.773913  7.449315    425.0
#        FLL   139.833333  9.196014   1041.0
# ...                 ...       ...      ...
# XWA    MSP    75.955556  3.842141    553.0
# YAK    CDV    38.172414  1.974735    213.0
#        JNU    34.736842  3.073657    198.0
# YUM    DFW   124.426230  7.161143   1022.0
#        PHX    32.012821  3.452885    160.0
#
# [5844 rows x 3 columns]

# %%
time_route.sort_values(by = ('AirTime', 'mean'))
# Out:
#                AirTime           Distance
#                   mean       std      min
# Origin Dest
# WRG    PSG   11.344828  2.705107     31.0
# PSG    WRG   11.800000  2.569706     31.0
# SJU    STT   16.298851  1.249325     68.0
# SFO    STS   16.446809  1.652515     66.0
# IAD    MDT   18.000000       NaN     94.0
# ...                ...       ...      ...
# PHX    LGA         NaN       NaN   2149.0
# PNS    MCI         NaN       NaN    743.0
# SMF    EWR         NaN       NaN   2500.0
# TTN    MIA         NaN       NaN   1047.0
# VPS    IND         NaN       NaN    637.0
#
# [5844 rows x 3 columns]

# %% [markdown]
# __Exercise__

# %% [markdown]
# Which plane has the highest average delay?
#
# We'll first group by `Tail_Number` and then calculate the relevant statistic for each group.
#
# 1. Get average delays for each plane, then show the top 10
#
# 2. Get both average delay and number of flights. Show the 10 planes with the most flights
#
# 3. Get both average delay and number of flights.  Show the 10 planes with the worst delays from those that had at least 10 flights.

# %% [markdown]
# 1.

# %%
flights.groupby('Tail_Number')['DepDelay'].mean().sort_values(ascending=False).head(10)
# Out:
# Tail_Number
# N669UA    199.000000
# N2142U    190.000000
# N762AN     73.000000
# N388AA     61.736842
# N343AN     61.400000
# N112AN     58.750000
# N204UA     55.866667
# N447UA     53.727273
# N216UA     51.500000
# N234JQ     50.333333
# Name: DepDelay, dtype: float64

# %% [markdown]
# 2.

# %%
delays = flights.groupby('Tail_Number')['DepDelay'].agg(['mean', 'count'])
delays.sort_values(by = 'count', ascending = False).head(10)
# Out:
#                  mean  count
# Tail_Number
# N494HA      -3.450667    375
# N615AS      -8.239892    371
# N493HA      -4.204986    361
# N484HA      -2.836620    355
# N488HA      -3.448276    348
# N618AS      -6.438596    342
# N644AS      -2.377193    342
# N485HA      -2.911504    339
# N479HA      -3.924925    333
# N491HA      -3.621212    330

# %% [markdown]
# 3.

# %%
delays.sort_values(by = 'mean', ascending = False).head(10)
# Out:
#                    mean  count
# Tail_Number
# N669UA       199.000000      1
# N2142U       190.000000      2
# N762AN        73.000000      1
# N388AA        61.736842     19
# N343AN        61.400000     25
# N112AN        58.750000     12
# N204UA        55.866667     30
# N447UA        53.727273     22
# N216UA        51.500000     10
# N234JQ        50.333333      3

# %%
delays[delays['count'] > 10].sort_values(by = 'mean', ascending = False).head(10)
# Out:
#                   mean  count
# Tail_Number
# N388AA       61.736842     19
# N343AN       61.400000     25
# N112AN       58.750000     12
# N204UA       55.866667     30
# N447UA       53.727273     22
# N397AN       47.437500     16
# N812AA       46.775000     40
# N510UA       45.416667     12
# N691AA       44.533333     45
# N412UA       44.391304     46

# %% [markdown]
# If we take the delays_per_day

# %%
delays_per_day = flights.groupby(flights['FlightDate'].str[-5:])['DepDelay'].describe()
delays_per_day
# Out:
#               count      mean        std   min  25%  50%  75%     max
# FlightDate
# 03-01       20393.0  3.414015  37.087099 -27.0 -6.0 -3.0  0.0  1824.0
# 03-02       21276.0  2.150733  36.984158 -32.0 -7.0 -4.0 -1.0  1919.0
# 03-03       20414.0  0.742677  35.954623 -38.0 -7.0 -5.0 -1.0  1625.0
# 03-04       20664.0  5.037989  36.212691 -37.0 -7.0 -4.0  1.0  1458.0
# 03-05       21388.0  2.508790  35.418548 -38.0 -7.0 -4.0  0.0  1432.0
# ...             ...       ...        ...   ...  ...  ...  ...     ...
# 04-26        5015.0 -3.477168  23.114546 -62.0 -9.0 -6.0 -4.0   572.0
# 04-27        5056.0 -4.442642  18.461623 -64.0 -9.0 -6.0 -4.0   671.0
# 04-28        4826.0 -3.506424  21.372949 -60.0 -9.0 -6.0 -3.0   720.0
# 04-29        4954.0 -3.463868  24.552930 -71.0 -9.0 -6.0 -3.0  1018.0
# 04-30        5269.0 -2.963560  23.289392 -39.0 -9.0 -6.0 -3.0   668.0
#
# [61 rows x 8 columns]

# %%
from sklearn.preprocessing import StandardScaler

delays_per_day[StandardScaler().fit_transform(delays_per_day) > 3]
# Out:
#               count      mean        std   min  25%  50%  75%     max
# FlightDate
# 03-13       21807.0  9.132572  45.256368 -31.0 -6.0 -3.0  6.0  2579.0
# 03-13       21807.0  9.132572  45.256368 -31.0 -6.0 -3.0  6.0  2579.0
# 03-13       21807.0  9.132572  45.256368 -31.0 -6.0 -3.0  6.0  2579.0

# %%
delays_per_day.std()
# Out:
# count    6570.827088
# mean        3.288521
# std         6.848043
# min        12.105344
# 25%         1.271590
# 50%         1.017067
# 75%         1.776901
# max       434.039229
# dtype: float64

# %%
delays_per_day['count'] = delays_per_day['count'] / 1000
delays_per_day['max'] = delays_per_day['max'] / 150

delays_per_day.plot()

# %%
delays_per_day[['max', 'mean', '50%']].plot()

# %%
plt.hist(flights['DepDelay'].dropna(), bins= range(-50, 2500, 5));
plt.gca().set_xlim(-50, 1000)
plt.yscale('log')

# %%
plt.hist(flights['DepDelay'].dropna(), bins=list(range(-50,-25, 5)) + list(range(-25, 25)) + list(range(25, 2500, 5)));
plt.gca().set_xlim(-50, 1000)
plt.yscale('log')

# %% [markdown]
# ## Group-wise Operations and Transformations

# %% [markdown]
# ### Apply: General split-apply-combine

# %%
flights.groupby('Tail_Number')[['Distance']]\
    .apply(lambda df: df['Distance'].max() - df['Distance'].min())
# Out:
# Tail_Number
# 215NV      733.0
# 216NV     1015.0
# 217NV     1148.0
# 218NV     1228.0
# 219NV      400.0
#            ...
# N998JE    1437.0
# N998NN    2113.0
# N999DN     818.0
# N999JB     125.0
# N999JQ    1693.0
# Length: 5561, dtype: float64

# %%
def sample_ten_percent(series):
    return series.sample(len(series) // 10)

stratified_sample = flights.groupby('Origin').apply(sample_ten_percent)
stratified_sample
# Out:
#                FlightDate  DayOfWeek Reporting_Airline Tail_Number  \
# Origin
# ABE    565052  2020-03-02          1                OO      N921EV
#        269884  2020-03-01          7                G4       228NV
#        14133   2020-04-04          6                MQ      N663AR
#        272081  2020-03-07          6                G4       224NV
#        31927   2020-04-01          3                OH      N578NN
# ...                   ...        ...               ...         ...
# YUM    520798  2020-03-10          2                OO      N606SK
#        43974   2020-04-07          2                OO      N761ND
#        42926   2020-04-04          6                OO      N759EV
#        522425  2020-03-11          3                OO      N745SK
#        299111  2020-04-01          3                YV         NaN
#
#                Flight_Number_Reporting_Airline Origin  \
# Origin
# ABE    565052                             4321    ABE
#        269884                             2635    ABE
#        14133                              4052    ABE
#        272081                              279    ABE
#        31927                              5314    ABE
# ...                                        ...    ...
# YUM    520798                             2967    YUM
#        43974                              2967    YUM
#        42926                              2967    YUM
#        522425                             3029    YUM
#        299111                             5852    YUM
#
#                                OriginCityName OriginStateName  \
# Origin
# ABE    565052  Allentown/Bethlehem/Easton, PA    Pennsylvania
#        269884  Allentown/Bethlehem/Easton, PA    Pennsylvania
#        14133   Allentown/Bethlehem/Easton, PA    Pennsylvania
#        272081  Allentown/Bethlehem/Easton, PA    Pennsylvania
#        31927   Allentown/Bethlehem/Easton, PA    Pennsylvania
# ...                                       ...             ...
# YUM    520798                        Yuma, AZ         Arizona
#        43974                         Yuma, AZ         Arizona
#        42926                         Yuma, AZ         Arizona
#        522425                        Yuma, AZ         Arizona
#        299111                        Yuma, AZ         Arizona
#
#                OriginCityMarketID Dest            DestCityName  \
# Origin
# ABE    565052               30135  DTW             Detroit, MI
#        269884               30135  SRQ  Sarasota/Bradenton, FL
#        14133                30135  ORD             Chicago, IL
#        272081               30135  PIE      St. Petersburg, FL
#        31927                30135  CLT           Charlotte, NC
# ...                           ...  ...                     ...
# YUM    520798               33785  PHX             Phoenix, AZ
#        43974                33785  PHX             Phoenix, AZ
#        42926                33785  PHX             Phoenix, AZ
#        522425               33785  DFW   Dallas/Fort Worth, TX
#        299111               33785  PHX             Phoenix, AZ
#
#                 DestStateName  DestCityMarketID  DepTime  DepDelay  AirTime  \
# Origin
# ABE    565052        Michigan             31295    543.0      -2.0     88.0
#        269884         Florida             34986    726.0      11.0    130.0
#        14133         Illinois             30977   1458.0      -9.0     97.0
#        272081         Florida             33195    550.0     -10.0    128.0
#        31927   North Carolina             31057   1124.0     -11.0     65.0
# ...                       ...               ...      ...       ...      ...
# YUM    520798         Arizona             30466    557.0      -3.0     26.0
#        43974          Arizona             30466    616.0     -11.0     29.0
#        42926          Arizona             30466      NaN       NaN      NaN
#        522425           Texas             30194    456.0      -4.0    124.0
#        299111         Arizona             30466      NaN       NaN      NaN
#
#                Distance
# Origin
# ABE    565052     425.0
#        269884    1000.0
#        14133      654.0
#        272081     970.0
#        31927      481.0
# ...                 ...
# YUM    520798     160.0
#        43974      160.0
#        42926      160.0
#        522425    1022.0
#        299111     160.0
#
# [96000 rows x 17 columns]

# %% [markdown]
# Suppresing the group keys

# %%
stratified_sample = flights.groupby('Origin', group_keys=False).apply(sample_ten_percent)
stratified_sample
# Out:
#         FlightDate  DayOfWeek Reporting_Airline Tail_Number  \
# 65411   2020-04-12          7                OO      N8932C
# 14137   2020-04-08          3                MQ      N674RJ
# 25905   2020-04-13          1                OH      N575NN
# 1136    2020-04-03          5                G4         NaN
# 533854  2020-03-13          5                OO      N455CA
# ...            ...        ...               ...         ...
# 524091  2020-03-12          4                OO      N719SK
# 454497  2020-03-14          6                YV       N905J
# 299060  2020-04-06          1                YV         NaN
# 521662  2020-03-05          4                OO      N715SK
# 454447  2020-03-18          3                YV      N942LR
#
#         Flight_Number_Reporting_Airline Origin  \
# 65411                              4577    ABE
# 14137                              4052    ABE
# 25905                              5105    ABE
# 1136                               2516    ABE
# 533854                             4321    ABE
# ...                                 ...    ...
# 524091                             3100    YUM
# 454497                             5852    YUM
# 299060                             5851    YUM
# 521662                             2994    YUM
# 454447                             5851    YUM
#
#                         OriginCityName OriginStateName  OriginCityMarketID  \
# 65411   Allentown/Bethlehem/Easton, PA    Pennsylvania               30135
# 14137   Allentown/Bethlehem/Easton, PA    Pennsylvania               30135
# 25905   Allentown/Bethlehem/Easton, PA    Pennsylvania               30135
# 1136    Allentown/Bethlehem/Easton, PA    Pennsylvania               30135
# 533854  Allentown/Bethlehem/Easton, PA    Pennsylvania               30135
# ...                                ...             ...                 ...
# 524091                        Yuma, AZ         Arizona               33785
# 454497                        Yuma, AZ         Arizona               33785
# 299060                        Yuma, AZ         Arizona               33785
# 521662                        Yuma, AZ         Arizona               33785
# 454447                        Yuma, AZ         Arizona               33785
#
#        Dest   DestCityName   DestStateName  DestCityMarketID  DepTime  \
# 65411   DTW    Detroit, MI        Michigan             31295   1721.0
# 14137   ORD    Chicago, IL        Illinois             30977   1459.0
# 25905   CLT  Charlotte, NC  North Carolina             31057    558.0
# 1136    SAV   Savannah, GA         Georgia             34685      NaN
# 533854  DTW    Detroit, MI        Michigan             31295    541.0
# ...     ...            ...             ...               ...      ...
# 524091  PHX    Phoenix, AZ         Arizona             30466   1652.0
# 454497  PHX    Phoenix, AZ         Arizona             30466   1229.0
# 299060  PHX    Phoenix, AZ         Arizona             30466      NaN
# 521662  PHX    Phoenix, AZ         Arizona             30466   1020.0
# 454447  PHX    Phoenix, AZ         Arizona             30466   2038.0
#
#         DepDelay  AirTime  Distance
# 65411      -14.0     74.0     425.0
# 14137       -8.0    110.0     654.0
# 25905       -6.0    100.0     481.0
# 1136         NaN      NaN     669.0
# 533854      -4.0     85.0     425.0
# ...          ...      ...       ...
# 524091      -1.0     31.0     160.0
# 454497       2.0     30.0     160.0
# 299060       NaN      NaN     160.0
# 521662      28.0     31.0     160.0
# 454447      19.0     35.0     160.0
#
# [96000 rows x 17 columns]

# %% [markdown]
# ### Quantile and bucket analysis

# %%
pd.cut(flights['Distance'], bins = (0, 100, 600, 10000))
# Out:
# 0         (600, 10000]
# 1         (600, 10000]
# 2           (100, 600]
# 3           (100, 600]
# 4           (100, 600]
#               ...
# 313377    (600, 10000]
# 313378      (100, 600]
# 313379      (100, 600]
# 313380      (100, 600]
# 313381    (600, 10000]
# Name: Distance, Length: 961611, dtype: category
# Categories (3, interval[int64]): [(0, 100] < (100, 600] < (600, 10000]]

# %%
haul = pd.cut(flights['Distance'], bins = (0, 100, 600, 10000))

flights.groupby(haul)[['AirTime', 'DepDelay']]\
    .agg(['mean', 'median', 'std', 'count'])
# Out:
#                  AirTime                            DepDelay         \
#                     mean median        std   count      mean median
# Distance
# (0, 100]       23.501723   23.0   4.502007    9864 -0.241962   -6.0
# (100, 600]     59.579465   59.0  18.119129  324582 -0.191152   -5.0
# (600, 10000]  155.623871  137.0  64.716901  385804  0.700379   -5.0
#
#
#                     std   count
# Distance
# (0, 100]      38.953161    9890
# (100, 600]    33.674868  325087
# (600, 10000]  33.084590  386679

# %% [markdown]
# __Exercise__

# %% [markdown]
# Show cities by descending number of airports

# %%
flights.sample(5)
# Out:
#         FlightDate  DayOfWeek Reporting_Airline Tail_Number  \
# 578037  2020-03-10          2                OO      N969SW
# 429316  2020-03-24          2                WN      N752SW
# 270181  2020-03-27          5                G4         NaN
# 35992   2020-04-14          2                OH      N614NN
# 612519  2020-03-25          3                UA         NaN
#
#         Flight_Number_Reporting_Airline Origin          OriginCityName  \
# 578037                             5996    DEN              Denver, CO
# 429316                             2031    SEA             Seattle, WA
# 270181                             1819    PGD         Punta Gorda, FL
# 35992                              5444    SRQ  Sarasota/Bradenton, FL
# 612519                              812    CMH            Columbus, OH
#
#        OriginStateName  OriginCityMarketID Dest       DestCityName  \
# 578037        Colorado               30325  GTF    Great Falls, MT
# 429316      Washington               30559  OAK        Oakland, CA
# 270181         Florida               34082  IND   Indianapolis, IN
# 35992          Florida               34986  CLT      Charlotte, NC
# 612519            Ohio               31066  SFO  San Francisco, CA
#
#          DestStateName  DestCityMarketID  DepTime  DepDelay  AirTime  Distance
# 578037         Montana             31895   1128.0      -3.0     93.0     623.0
# 429316      California             32457   1311.0      -4.0    100.0     672.0
# 270181         Indiana             32337      NaN       NaN      NaN     916.0
# 35992   North Carolina             31057   1659.0     -10.0     84.0     547.0
# 612519      California             32457      NaN       NaN      NaN    2120.0

# %%
flights.groupby('OriginCityName')['Origin'].nunique().sort_values(ascending=False).head(10)
# Out:
# OriginCityName
# Washington, DC     2
# Chicago, IL        2
# Houston, TX        2
# Mobile, AL         2
# Phoenix, AZ        2
# New York, NY       2
# Columbus, OH       2
# Garden City, KS    1
# Fort Myers, FL     1
# Fort Smith, AR     1
# Name: Origin, dtype: int64

# %%
flights.groupby('OriginCityName').nunique()
# Out:
#                  FlightDate  DayOfWeek  Reporting_Airline  Tail_Number  \
# OriginCityName
# Aberdeen, SD             61          7                  1           55
# Abilene, TX              61          7                  1           68
# Adak Island, AK          17          2                  1            9
# Aguadilla, PR            36          7                  3          115
# Akron, OH                61          7                  8          267
# ...                     ...        ...                ...          ...
# Wilmington, NC           61          7                  7          315
# Worcester, MA            59          7                  2           85
# Wrangell, AK             61          7                  1           11
# Yakutat, AK              61          7                  1           19
# Yuma, AZ                 61          7                  2          100
#
#                  Flight_Number_Reporting_Airline  Origin  OriginStateName  \
# OriginCityName
# Aberdeen, SD                                   2       1                1
# Abilene, TX                                    9       1                1
# Adak Island, AK                                1       1                1
# Aguadilla, PR                                  9       1                1
# Akron, OH                                     26       1                1
# ...                                          ...     ...              ...
# Wilmington, NC                                49       1                1
# Worcester, MA                                  4       1                1
# Wrangell, AK                                   2       1                1
# Yakutat, AK                                    2       1                1
# Yuma, AZ                                      12       1                1
#
#                  OriginCityMarketID  Dest  DestCityName  DestStateName  \
# OriginCityName
# Aberdeen, SD                      1     1             1              1
# Abilene, TX                       1     1             1              1
# Adak Island, AK                   1     1             1              1
# Aguadilla, PR                     1     4             4              3
# Akron, OH                         1    11            11              9
# ...                             ...   ...           ...            ...
# Wilmington, NC                    1     6             6              6
# Worcester, MA                     1     4             4              3
# Wrangell, AK                      1     2             2              1
# Yakutat, AK                       1     2             2              1
# Yuma, AZ                          1     2             2              2
#
#                  DestCityMarketID  DepTime  DepDelay  AirTime  Distance
# OriginCityName
# Aberdeen, SD                    1       55        28       16         1
# Abilene, TX                     1      127        41       19         1
# Adak Island, AK                 1       13        14       14         1
# Aguadilla, PR                   3      109        59       66         4
# Akron, OH                      10      252        83      103        11
# ...                           ...      ...       ...      ...       ...
# Wilmington, NC                  6      305        74       90         6
# Worcester, MA                   4       83        41       68         4
# Wrangell, AK                    2       72        51       23         2
# Yakutat, AK                     2       83        57       14         2
# Yuma, AZ                        2      137        51       42         2
#
# [346 rows x 16 columns]

# %%
flights[['OriginCityName', 'Origin']].drop_duplicates()\
    .groupby('OriginCityName').count().sort_values(by='Origin', ascending=False)
# Out:
#                  Origin
# OriginCityName
# New York, NY          2
# Chicago, IL           2
# Mobile, AL            2
# Phoenix, AZ           2
# Columbus, OH          2
# ...                 ...
# Gainesville, FL       1
# Fresno, CA            1
# Fort Wayne, IN        1
# Fort Smith, AR        1
# Yuma, AZ              1
#
# [346 rows x 1 columns]

# %% [markdown]
# The list above doesn't correspond to our intuitive expectation, probably. That is because airports serving the same general area may be located within several different city limits. This is encapsulated by the "market" concept in commercial aviation.
#
# Find the 10 markets with the most airports, and which airports are included in them.
#
# Hint: there is an aggregation that we haven't used yet that can come in really handy. Search for it in the [list of functions in groupby](https://pandas.pydata.org/pandas-docs/stable/reference/groupby.html)

# %%
flights[flights['OriginCityName'] == 'New York, NY'].sample(5)
# Out:
#         FlightDate  DayOfWeek Reporting_Airline Tail_Number  \
# 124568  2020-04-03          5                AA         NaN
# 481869  2020-03-16          1                YX      N871RW
# 283836  2020-03-27          5                MQ         NaN
# 289861  2020-03-27          5                MQ         NaN
# 2994    2020-03-20          5                9E      N331PQ
#
#         Flight_Number_Reporting_Airline Origin OriginCityName OriginStateName  \
# 124568                             2122    LGA   New York, NY        New York
# 481869                             6053    LGA   New York, NY        New York
# 283836                             3320    LGA   New York, NY        New York
# 289861                             3546    LGA   New York, NY        New York
# 2994                               4820    LGA   New York, NY        New York
#
#         OriginCityMarketID Dest    DestCityName   DestStateName  \
# 124568               31703  BOS      Boston, MA   Massachusetts
# 481869               31703  CLT   Charlotte, NC  North Carolina
# 283836               31703  ORD     Chicago, IL        Illinois
# 289861               31703  ROA     Roanoke, VA        Virginia
# 2994                 31703  PIT  Pittsburgh, PA    Pennsylvania
#
#         DestCityMarketID  DepTime  DepDelay  AirTime  Distance
# 124568             30721      NaN       NaN      NaN     184.0
# 481869             31057    750.0     -10.0     97.0     544.0
# 283836             30977      NaN       NaN      NaN     733.0
# 289861             34574      NaN       NaN      NaN     405.0
# 2994               30198   1725.0      -1.0     61.0     335.0

# %%
flights.groupby('OriginCityMarketID')['Origin'].nunique().sort_values(ascending=False)
# Out:
# OriginCityMarketID
# 31703    6
# 32575    5
# 30852    3
# 32457    3
# 30721    3
#         ..
# 33277    1
# 33290    1
# 33304    1
# 33316    1
# 30070    1
# Name: Origin, Length: 328, dtype: int64

# %%
# %%time

flights.groupby('OriginCityMarketID')['Origin']\
       .agg(['nunique', 'unique'])\
       .sort_values(by='nunique', ascending=False)\
       .head(10)
# Out:
# CPU times: user 288 ms, sys: 1.18 ms, total: 289 ms
# Wall time: 294 ms
#                     nunique                          unique
# OriginCityMarketID
# 31703                     6  [JFK, LGA, HPN, EWR, SWF, ISP]
# 32575                     5       [LAX, ONT, SNA, BUR, LGB]
# 32457                     3                 [SFO, SJC, OAK]
# 30852                     3                 [DCA, IAD, BWI]
# 30721                     3                 [PVD, BOS, MHT]
# 30977                     2                      [ORD, MDW]
# 30194                     2                      [DFW, DAL]
# 31453                     2                      [IAH, HOU]
# 32467                     2                      [MIA, FLL]
# 33667                     2                      [ORF, PHF]

# %% [markdown]
# ## Pivot tables and Cross-tabulation

# %%
flights.columns
# Out:
# Index(['FlightDate', 'DayOfWeek', 'Reporting_Airline', 'Tail_Number',
#        'Flight_Number_Reporting_Airline', 'Origin', 'OriginCityName',
#        'OriginStateName', 'OriginCityMarketID', 'Dest', 'DestCityName',
#        'DestStateName', 'DestCityMarketID', 'DepTime', 'DepDelay', 'AirTime',
#        'Distance'],
#       dtype='object')

# %%
flights.pivot_table(index='Reporting_Airline', columns='DayOfWeek', values='DepDelay')
# Out:
# DayOfWeek                 1         2         3         4         5         6  \
# Reporting_Airline
# 9E                -1.707888 -2.419213 -1.649101 -1.063947  5.429478 -0.854762
# AA                -0.224525 -0.559173  2.343172  1.606453  3.250790  0.469832
# AS                -3.028130 -3.333931 -3.049471 -3.571046 -0.464286 -0.625544
# B6                -0.271827 -2.905212 -1.211667 -3.060995  1.330606  1.251513
# DL                 0.398689 -0.788563  2.626048  2.006141  2.021452  0.822409
# EV                -3.330180 -4.691929 -2.401846 -4.482199 -1.713975 -3.783871
# F9                 0.310252 -0.458415 -0.026334  0.439729  4.596370  1.902635
# G4                 5.367169 -1.790609  0.089943  9.346806  7.529054  4.461660
# HA                -0.941385  8.142466 -1.621141 -2.818182 -2.800826 -2.882759
# MQ                -2.696903 -3.062567 -1.486822 -0.437968  0.932697 -0.627907
# NK                 4.820390  3.690234  4.221722  3.396692  5.467430  4.041904
# OH                 4.610658  0.932104  2.290122  1.276879  3.315338 -0.138889
# OO                 0.334075 -1.242576  0.626029  1.556310  3.820079  0.794643
# UA                -1.800590 -0.736026 -1.412125 -0.300822  5.105694  1.248512
# WN                -1.234474 -1.054350 -1.022444 -0.083004  0.196322 -0.215981
# YV                 2.203698 -0.400274  5.694783  3.696464  3.986076  2.892055
# YX                -3.736144 -4.222489 -3.384430 -3.622343  1.810401 -2.532226
#
# DayOfWeek                 7
# Reporting_Airline
# 9E                -2.967217
# AA                 0.539833
# AS                 0.015668
# B6                 1.907815
# DL                 0.357781
# EV                -3.053221
# F9                 0.082505
# G4                 4.709606
# HA                -3.590426
# MQ                -2.359440
# NK                 3.947994
# OH                 0.850226
# OO                 0.866443
# UA                 0.397874
# WN                -0.459891
# YV                 2.640602
# YX                -2.537602

# %%
# %%time
flights.pivot_table(index=['Reporting_Airline', 'Flight_Number_Reporting_Airline'], 
                    columns='DayOfWeek', 
                    values=['DepDelay', 'Distance'], 
                    aggfunc=['mean', 'std'])
# Out:
# CPU times: user 473 ms, sys: 6.67 ms, total: 480 ms
# Wall time: 599 ms
#                                                         mean             \
#                                                     DepDelay
# DayOfWeek                                                  1          2
# Reporting_Airline Flight_Number_Reporting_Airline
# 9E                4628                                   NaN        NaN
#                   4629                             -7.500000   0.500000
#                   4633                                   NaN        NaN
#                   4634                             -3.500000  -5.625000
#                   4635                             -6.500000 -10.000000
# ...                                                      ...        ...
# YX                6139                             -5.666667  -4.833333
#                   6140                             -3.000000  16.000000
#                   6141                            -14.000000 -16.000000
#                   6142                             27.428571  -8.625000
#                   6143                             -9.000000  -9.000000
#
#                                                                          \
#
# DayOfWeek                                                  3          4
# Reporting_Airline Flight_Number_Reporting_Airline
# 9E                4628                                   NaN        NaN
#                   4629                            -11.000000  -2.500000
#                   4633                                   NaN        NaN
#                   4634                             -6.000000  16.200000
#                   4635                             -8.000000 -22.000000
# ...                                                      ...        ...
# YX                6139                             -6.833333  -8.250000
#                   6140                            -10.500000 -11.333333
#                   6141                            -10.500000 -10.333333
#                   6142                             -5.833333  -5.166667
#                   6143                            -11.000000  -7.500000
#
#                                                                             \
#
# DayOfWeek                                               5     6          7
# Reporting_Airline Flight_Number_Reporting_Airline
# 9E                4628                                NaN   NaN        NaN
#                   4629                             -4.500 -10.0 -16.500000
#                   4633                                NaN   NaN        NaN
#                   4634                             -8.250  -6.5  -4.625000
#                   4635                             -7.500 -14.0  -9.500000
# ...                                                   ...   ...        ...
# YX                6139                             -2.400  -7.0  11.250000
#                   6140                             31.000   NaN  -6.400000
#                   6141                             -0.500  -8.5  45.000000
#                   6142                             -0.375   7.8  -6.666667
#                   6143                             -5.500  -6.0        NaN
#
#                                                                            \
#                                                      Distance
# DayOfWeek                                                   1           2
# Reporting_Airline Flight_Number_Reporting_Airline
# 9E                4628                             610.000000  610.000000
#                   4629                             500.000000  500.000000
#                   4633                                    NaN         NaN
#                   4634                             645.000000  645.000000
#                   4635                             503.000000  503.000000
# ...                                                       ...         ...
# YX                6139                             797.666667  797.666667
#                   6140                             200.000000  200.000000
#                   6141                             479.000000  479.000000
#                   6142                             987.000000  987.000000
#                   6143                             200.000000  200.000000
#
#                                                                             \
#
# DayOfWeek                                                   3            4
# Reporting_Airline Flight_Number_Reporting_Airline
# 9E                4628                             610.000000   610.000000
#                   4629                             500.000000   500.000000
#                   4633                             273.000000   273.000000
#                   4634                             645.000000   645.000000
#                   4635                             397.666667   503.000000
# ...                                                       ...          ...
# YX                6139                             797.666667   742.200000
#                   6140                             200.000000   253.333333
#                   6141                             479.000000   479.000000
#                   6142                             987.000000  1047.000000
#                   6143                             200.000000   200.000000
#
#                                                                         \
#
# DayOfWeek                                                    5       6
# Reporting_Airline Flight_Number_Reporting_Airline
# 9E                4628                              610.000000     NaN
#                   4629                              500.000000   500.0
#                   4633                              273.000000   273.0
#                   4634                              645.000000   645.0
#                   4635                              503.000000   503.0
# ...                                                        ...     ...
# YX                6139                              742.200000   556.5
#                   6140                              253.333333     NaN
#                   6141                              479.000000   867.0
#                   6142                             1047.000000  1059.0
#                   6143                              200.000000   306.0
#
#                                                                      std  \
#                                                                 DepDelay
# DayOfWeek                                                   7          1
# Reporting_Airline Flight_Number_Reporting_Airline
# 9E                4628                             610.000000        NaN
#                   4629                             500.000000   3.535534
#                   4633                                    NaN        NaN
#                   4634                             645.000000   6.391959
#                   4635                             503.000000   4.949747
# ...                                                       ...        ...
# YX                6139                             763.000000   3.076795
#                   6140                             248.000000   5.656854
#                   6141                             479.000000   7.071068
#                   6142                             969.857143  60.637879
#                   6143                                    NaN        NaN
#
#                                                                         \
#
# DayOfWeek                                                  2         3
# Reporting_Airline Flight_Number_Reporting_Airline
# 9E                4628                                   NaN       NaN
#                   4629                             14.849242       NaN
#                   4633                                   NaN       NaN
#                   4634                              5.097268  1.414214
#                   4635                              0.000000  2.828427
# ...                                                      ...       ...
# YX                6139                              4.119061  3.125167
#                   6140                             33.941125  3.535534
#                   6141                              7.071068  3.535534
#                   6142                              3.852179  2.483277
#                   6143                                   NaN       NaN
#
#                                                                          \
#
# DayOfWeek                                                  4          5
# Reporting_Airline Flight_Number_Reporting_Airline
# 9E                4628                                   NaN        NaN
#                   4629                              3.535534   0.707107
#                   4633                                   NaN        NaN
#                   4634                             59.085249   3.693624
#                   4635                                   NaN   3.535534
# ...                                                      ...        ...
# YX                6139                              0.957427   7.503333
#                   6140                              4.509250  33.045423
#                   6141                             11.150486   7.778175
#                   6142                              3.544949  10.336309
#                   6143                              0.707107   0.707107
#
#                                                                          \
#
# DayOfWeek                                                  6          7
# Reporting_Airline Flight_Number_Reporting_Airline
# 9E                4628                                   NaN        NaN
#                   4629                                   NaN   9.192388
#                   4633                                   NaN        NaN
#                   4634                              2.203893   4.068608
#                   4635                              5.656854   0.707107
# ...                                                      ...        ...
# YX                6139                              3.366502  41.843956
#                   6140                                   NaN   4.037326
#                   6141                              0.707107  73.539105
#                   6142                             35.891503   4.179314
#                   6143                              1.000000        NaN
#
#                                                                            \
#                                                      Distance
# DayOfWeek                                                   1           2
# Reporting_Airline Flight_Number_Reporting_Airline
# 9E                4628                               0.000000    0.000000
#                   4629                               0.000000    0.000000
#                   4633                                    NaN         NaN
#                   4634                               0.000000    0.000000
#                   4635                               0.000000    0.000000
# ...                                                       ...         ...
# YX                6139                             107.410738  107.410738
#                   6140                               0.000000    0.000000
#                   6141                               0.000000    0.000000
#                   6142                             128.285396  128.285396
#                   6143                               0.000000    0.000000
#
#                                                                            \
#
# DayOfWeek                                                   3           4
# Reporting_Airline Flight_Number_Reporting_Airline
# 9E                4628                               0.000000    0.000000
#                   4629                               0.000000    0.000000
#                   4633                                    NaN    0.000000
#                   4634                               0.000000    0.000000
#                   4635                             182.442685    0.000000
# ...                                                       ...         ...
# YX                6139                             107.410738  113.926292
#                   6140                               0.000000   46.188022
#                   6141                               0.000000    0.000000
#                   6142                             128.285396  111.098412
#                   6143                               0.000000    0.000000
#
#                                                                            \
#
# DayOfWeek                                                   5           6
# Reporting_Airline Flight_Number_Reporting_Airline
# 9E                4628                               0.000000         NaN
#                   4629                               0.000000    0.000000
#                   4633                               0.000000    0.000000
#                   4634                               0.000000    0.000000
#                   4635                               0.000000    0.000000
# ...                                                       ...         ...
# YX                6139                             113.926292  207.000000
#                   6140                              46.188022         NaN
#                   6141                               0.000000    0.000000
#                   6142                             111.098412  107.331263
#                   6143                               0.000000    0.000000
#
#
#
# DayOfWeek                                                   7
# Reporting_Airline Flight_Number_Reporting_Airline
# 9E                4628                               0.000000
#                   4629                               0.000000
#                   4633                                    NaN
#                   4634                               0.000000
#                   4635                               0.000000
# ...                                                       ...
# YX                6139                             120.088856
#                   6140                              43.817805
#                   6141                               0.000000
#                   6142                             128.285396
#                   6143                                    NaN
#
# [26336 rows x 28 columns]

# %%
delays = flights.pivot_table(columns='Reporting_Airline', values='DepDelay', index=['FlightDate'])
delays.plot()
