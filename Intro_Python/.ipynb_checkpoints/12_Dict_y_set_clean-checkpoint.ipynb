# %% [markdown]
# # DICT

# %% [markdown]
# __flexibly-sized collection of key-value pairs, where key and value are Python objects__
# A more common name for it is hash map or associative array.

# %% [markdown]
# __Creation__
# * curly braces { } and using colons : to separate keys and values
# * by using dict() method over (key, value) pairs
# * { } = empty dict

# %% [markdown]
# * curly braces { } and using colons : to separate keys and values

# %%
d1={'key1':1, 'key2':2}
print(d1)
# Out:
# {'key1': 1, 'key2': 2}

# %%
d1['key1']
# Out:
# 1

# %% [markdown]
# * by using dict() method over (key, value) pairs

# %%
d2=dict(key1=1, key2=2)
print(d2)

# %%
d2['key1']

# %%
d3=dict('key1'=1, 'key2'=2)
print(d3)

# %%
d3=dict((('key1',1), ('key2',2))) #tupla de 2D tuplas
print(d3)

# %%
d4=dict([('key1',1), ('key2',2)]) #lista de 2D tuplas
print(d4)

# %%
d5=dict([['key1',1], ['key2',2]]) #lista de 2D listas
print(d5)

# %%
d6=dict([['key1',1], ('key2',2)]) #lista de 2D tuplas/listas
print(d6)

# %% [markdown]
# __Using zip function to pair the elements__

# %%
values=(1, 2, 3, 4, 5)
keys=('a','b', 'c', 'd', 'e')
d7=dict(zip(keys, values))
print(d7)

# %%
zip(keys, values)

# %%
list(zip(keys, values))

# %% [markdown]
# __Elements can be accessed , inserted or set using the same syntax as accessing elements of a list or tuple__

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
d={'a':'some value', 'b':[1,2,3,4]}

# %%
d['St']='Split'
d[4]='integer'

# %%
d
# Out:
# {'a': 'some value', 'b': [1, 2, 3, 4], 'St': 'Split', 4: 'integer'}

# %%
d['4']='another string'

# %%
d
# Out:
# {'a': 'some value',
#  'b': [1, 2, 3, 4],
#  'St': 'Split',
#  4: 'integer',
#  '4': 'another string'}

# %% [markdown]
# __dirs are mutable__

# %%
d['4']='just string'
d
# Out:
# {'a': 'some value',
#  'b': [1, 2, 3, 4],
#  'St': 'Split',
#  4: 'integer',
#  '4': 'just string'}

# %% [markdown]
# __keys, values, items__

# %% [markdown]
# keys() = lists of the keys --> not sorted
# values() = lists of the values
# items() = object of items --> not sorted

# %%
d={'a': 'some value', 'b': [1, 2, 3, 4], 'St': 'Split', 4: 'integer'}
d.keys()
# Out:
# dict_keys(['a', 'b', 'St', 4])

# %%
d.values()
# Out:
# dict_values(['some value', [1, 2, 3, 4], 'Split', 'integer'])

# %%
d.items()
# Out:
# dict_items([('a', 'some value'), ('b', [1, 2, 3, 4]), ('St', 'Split'), (4, 'integer')])

# %%
list(d.items())
# Out:
# [('a', 'some value'), ('b', [1, 2, 3, 4]), ('St', 'Split'), (4, 'integer')]

# %%
for k,v in d.items():
    print(k,v)
# Out:
# a some value
# b [1, 2, 3, 4]
# St Split
# 4 integer
# abba 3

# %%
for k in d:
    print(k)
# Out:
# a
# b
# St
# 4
# abba

# %%
for k in d:
    print(k,d[k])
# Out:
# a some value
# b [1, 2, 3, 4]
# St Split
# 4 integer
# abba 3

# %%
d['abba']=3

# %%
list(d.items())
# Out:
# [('a', 'some value'),
#  ('b', [1, 2, 3, 4]),
#  ('St', 'Split'),
#  (4, 'integer'),
#  ('abba', 3)]

# %%
d.keys()
# Out:
# dict_keys(['a', 'b', 'St', 4, 'abba'])

# %% [markdown]
# __del vs pop vs popitem vs get vs clear__

# %%
del d['a']

# %%
d

# %%
del d['a']

# %%
b in d
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-25-a42d63895dd6> in <module>
# ----> 1 b in d
#
# NameError: name 'b' is not defined

# %%
'b' in d
# Out:
# True

# %%
if 'b' in d: del d['b']

# %%
k=del d['St']
# Out:
#   File "<ipython-input-28-d98119b10ca3>", line 1
#     k=del d['St']
#         ^
# SyntaxError: invalid syntax

# %%
k=d.pop('St')

# %%
print(k)
print(d)
# Out:
# Split
# {'a': 'some value', 4: 'integer', 'abba': 3}

# %%
k=d.pop('St')
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-31-b909e99f47d2> in <module>
# ----> 1 k=d.pop('St')
#
# KeyError: 'St'

# %%
k=d.get(4)
print(d)
print(k)
# Out:
# {'a': 'some value', 4: 'integer', 'abba': 3}
# integer

# %%
d.get(4)
# Out:
# 'integer'

# %%
d.clear()
d
# Out:
# {}

# %%
d={'a': 'some value', 'b': [1, 2, 3, 4], 'St': 'Split', 4: 'integer'}
d.popitem()
# Out:
# (4, 'integer')

# %%
d.popitem()
# Out:
# ('b', [1, 2, 3, 4])

# %% [markdown]
# __get & setdefault__

# %% [markdown]
# get(S, V) = search for S, and return V if you don’t find it

# %%
d={'a': 'some value', 'b': [1, 2, 3, 4], 'St': 'Split', 4: 'integer'}

# %%
d.get('a')

# %%
d.get('c')

# %%
d.get('c', "Not Found")

# %% [markdown]
# __setdefault()__ --> returns the key value available in the dictionary __if given key is not available__ then it will return provided default value __and insert it to the dictionary.__ If not provided, the default_value will be None

# %%
d.setdefault('a','Not Found')
d

# %%
d.setdefault('age','Not Found')
d

# %% [markdown]
# __update(D) = merged into and overwrite if key already exists__

# %%
d2={'a':"new value", 'bbb':'Dinamo'}
d.update(d2)
d

# %% [markdown]
# **Exercises**:
#
# 1) Create a function that for a given list of numbers, it returns a LIST with max, min and avg. Using that function for two different list of numbers, compute max of both maximums.
#
# 2) Modify your initial function in order to return also: First element of list, last element of list and number of elements in the list (len). Use this function to compute max number of elements between two lists.
#
# 3) Edit this last function to return Dict instead of List and try again both exercises. What do you think is better to avoid indexing errors and legacy code compatibility?

# %%
import numpy as np

# %%
def get_stats(list1):
    mean = sum(list1)/len(list1)
    # avg:np.mean(list1)
    return {'max':max(list1), 'min':min(list1),'avg':mean}

# %%
mynumbers = [1,2,3,4,5]
mynumbers2 = [10,2,3,4,0.1]

# %%
get_stats(mynumbers2)
# Out:
# {'max': 10, 'min': 0.1, 'avg': 3.8200000000000003}

# %%
get_stats(mynumbers)
# Out:
# {'max': 5, 'min': 1, 'avg': 3.0}

# %%
stats = get_stats(mynumbers)
np.mean(mynumbers)
# Out:
# 3.0

# %%
def get_stats(list1):
    mean = sum(list1)/len(list1)
    # avg:np.mean(list1)
    return {'max':max(list1), 'min':min(list1),'avg':mean,
            'first':list1[0], 'last':list1[-1], 'len':len(list1)}

# %%
def get_stats_list(list1):
    return max(list1),min(list1),np.mean(list1)
def get_stats_list2(list1):
        return max(list1),min(list1),np.mean(list1)

# %% [markdown]
# # SETS

# %% [markdown]
# * __unordered collection of unique elements__
#
# * like dicts, but keys only, no values
#
# * creation:
#  * curly braces { }  (no colons inside as no keys are present)
#  * by using set() method
#  * set()= empty  set
#  * set({ })= set({[ ]})=set(())=set()

# %%
s=set([2, 3, 4, 2, 2, 1, 3])
b={2, 3, 4, 2, 2, 1, 3}
type(s), type(b)
# Out:
# (set, set)

# %%
zip(dir(s), dir(b))

# %%
list(zip(dir(s), dir(b)))
# Out:
# [('__and__', '__and__'),
#  ('__class__', '__class__'),
#  ('__contains__', '__contains__'),
#  ('__delattr__', '__delattr__'),
#  ('__dir__', '__dir__'),
#  ('__doc__', '__doc__'),
#  ('__eq__', '__eq__'),
#  ('__format__', '__format__'),
#  ('__ge__', '__ge__'),
#  ('__getattribute__', '__getattribute__'),
#  ('__gt__', '__gt__'),
#  ('__hash__', '__hash__'),
#  ('__iand__', '__iand__'),
#  ('__init__', '__init__'),
#  ('__init_subclass__', '__init_subclass__'),
#  ('__ior__', '__ior__'),
#  ('__isub__', '__isub__'),
#  ('__iter__', '__iter__'),
#  ('__ixor__', '__ixor__'),
#  ('__le__', '__le__'),
#  ('__len__', '__len__'),
#  ('__lt__', '__lt__'),
#  ('__ne__', '__ne__'),
#  ('__new__', '__new__'),
#  ('__or__', '__or__'),
#  ('__rand__', '__rand__'),
#  ('__reduce__', '__reduce__'),
#  ('__reduce_ex__', '__reduce_ex__'),
#  ('__repr__', '__repr__'),
#  ('__ror__', '__ror__'),
#  ('__rsub__', '__rsub__'),
#  ('__rxor__', '__rxor__'),
#  ('__setattr__', '__setattr__'),
#  ('__sizeof__', '__sizeof__'),
#  ('__str__', '__str__'),
#  ('__sub__', '__sub__'),
#  ('__subclasshook__', '__subclasshook__'),
#  ('__xor__', '__xor__'),
#  ('add', 'add'),
#  ('clear', 'clear'),
#  ('copy', 'copy'),
#  ('difference', 'difference'),
#  ('difference_update', 'difference_update'),
#  ('discard', 'discard'),
#  ('intersection', 'intersection'),
#  ('intersection_update', 'intersection_update'),
#  ('isdisjoint', 'isdisjoint'),
#  ('issubset', 'issubset'),
#  ('issuperset', 'issuperset'),
#  ('pop', 'pop'),
#  ('remove', 'remove'),
#  ('symmetric_difference', 'symmetric_difference'),
#  ('symmetric_difference_update', 'symmetric_difference_update'),
#  ('union', 'union'),
#  ('update', 'update')]

# %%
a=set([2, 3, 'a', 4, 2, 2, 1, 3])
type(a)
# Out:
# set

# %%
c=set({})
d={}

# %%
type(c), type(d)
# Out:
# (set, dict)

# %%
e=set(())
f=set([])
type(e), type(f)
# Out:
# (set, set)

# %% [markdown]
# # support mathematical operations like:
# * a.union(b)			= a | b
# * a.intersection(b) 		= a & b
# * a.difference(b)		= a - b
# * a.symmetric_difference(b)	(XOR) = a ^ b
#
# __with update suffix --> updates the a set with the result__

# %%
a={1, 2, 3, 4, 5}
b={4, 5, 6, 7, 8}

a| b

# %%
a.union(b)

# %%
a.update(b) # union does not have union_update --> this is update 
a

# %%
a={1, 2, 3, 4, 5}
b={4, 5, 6, 7, 8}
a&b

# %%
a.intersection(b)

# %%
a-b

# %%
a.difference(b)

# %%
print(a, id(a))
a.difference_update(b)
print(a, id(a))
print(b)

# %%
b-a

# %%
a^b

# %%
a.symmetric_difference(b)

# %% [markdown]
# * You can also check if a set is a subset of (is contained in) or a superset of (contains all elements of) another set:
# * sets are equal if their contents are equal

# %%
a={1, 2, 3, 4, 5}
{3,1,2}.issubset(a)

# %%
a.issuperset({3,1,2})

# %%
{1,2,3}=={3,1,2}

# %% [markdown]
# __discard vs remove__

# %%
a.discard(1)
a

# %%
a.discard(1) #--> nothing happens if the element does not exist

# %%
a.remove(2)
a

# %%
a.remove(2) #--> raise a keyerror if not a member
