# %% [markdown]
# # Jupyter Notebook
# interactive computational environment,
# in which you can combine code execution, rich text, mathematics, plots and rich media.

# %% [markdown]
# Jupyther notebook app is a server that appears in your browser at a default address (http://localhost:8888).
# Closing the browser will not shut down the server.
# You can reopen the previous address and the  Jupyther notebook app  will be redisplayed.

# %% [markdown]
# When a notebook is opened, its “computational engine” (called the kernel) is automatically started.
# Closing the notebook browser tab, will not shut down the kernel, instead the kernel will keep running until is explicitly shut down.

# %% [markdown]
# ## Por qué mola el Jupyter Notebook?
#
# ### porque podemos escribir texto con formato
#
# como __este__ o _este_
#
# ### y tambien mates!
#
# dentro de un texto: $\mu = \frac{\sum_{i=0}^{i=n}{x_i}}{n}$, por ejemplo
#
# o como parrafo independiente
#
# $$\mu = \frac{\sum_{i=0}^{i=n}{x_i}}{n}$$
#
# ### o insertar enlaces e imagenes
#
# [rata topo desnuda](https://www.sciencemag.org/sites/default/files/styles/inline__450w__no_aspect/public/rat_16x9.jpg?itok=mm1kmwg1)
#
# ![rata topo desnuda](https://www.sciencemag.org/sites/default/files/styles/inline__450w__no_aspect/public/rat_16x9.jpg?itok=mm1kmwg1)

# %% [markdown]
# ---------------------

# %% [markdown]
# new line is achieved with 2 spaces at the and of the line
# and then new line ....

# %% [markdown]
# Podemos plotear asi (ver la documentacion de [matplotlib](https://matplotlib.org/contents.html))

# %%
# %pylab inline#import matplotlib and numpy together

# %%
import matplotlib.pyplot as plt
import numpy as np
# %matplotlib inline

xs = np.linspace(0, 2 * np.pi, 100)
ys = np.sin(xs)

plt.plot(xs, ys)
plt.plot(xs, np.cos(xs))

# %% [markdown]
# # Uso básico del notebook
#
# Recordad, tiene dos modos: el "azulito" para operar sobre celdas completas y el "verdecito" para editar el contenido de una celda.

# %% [markdown]
# help=modo azul + h

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# You can run the notebook document step-by-step (one cell a time) by pressing shift + enter.
# You can run the whole notebook in a single step by clicking on the menu Cell -> Run All.
# To restart the kernel (i.e. the computational engine), click on the menu Kernel -> Restart.
# This can be useful to start over a computation from scratch (e.g. variables are deleted, open files are closed, etc...).

# %% [markdown]
# How to stop the execution?
# How to change the cell type?
# How to change the name of the notebook?

# %%
print ("Hello")
# Out:
# Hello

# %%
a=5
b=6
a
# Out:
# 5

# %%
a=5
b=6
a
b
# Out:
# 6

# %%
a=5
b=6
print(a)
b
# Out:
# 5
# 6

# %%
a=5
b=6
b
b+a
# Out:
# 11

# %%
print("hola", 'q', 'tal', sep="^")
# Out:
# hola^q^tal

# %%
a=3 ; b=5

# %%
type(a)
# Out:
# int

# %%
a="trrtr"

# %%
type(a)
# Out:
# str

# %%
a.capitalize()
# Out:
# 'Trrtr'

# %%
a.upper()
# Out:
# 'TRRTR'

# %% [markdown]
# ----------------------------

# %% [markdown]
# Shift+tab=help over the command

# %%
# Semicolons can be used, to separate multiple statements on a single line (a = 5; b = 6; c = 7)
# Comments with #

# %% [markdown]
# ### Python is strongly-typed language (every object has a specific type (or class))

# %% [markdown]
# ----------------------------

# %% [markdown]
# # The Basics - Objects in Python

# %% [markdown]
# ----------------------------

# %% [markdown]
# ### Everything is an object
#
# ##### Each object has an associated type, internal data and typically some attributes
# - type() – get the type of an object

# %% [markdown]
# #### object references in Python have no type associated with them --> type information is stored in the object itself.

# %% [markdown]
# ----------------------------

# %% [markdown]
# ## Scalar Types

# %% [markdown]
# - int = Signed integer with maximum value determined by the platform.
# - long = Arbitrary precision signed integer. Large int values are automatically converted to long.
# - float = Double-precision (64-bit) floating point number. Note there is no separate double type.
# - str = String type
# - bool = A True or False value
# - None = The Python “null” value (only one instance of the None object exists)

# %% [markdown]
# ----------------------------

# %% [markdown]
# ## Data Structures

# %% [markdown]
# - lists: one-dimensional, variable-length, mutable sequence of Python objects
#  - creation:
#    - using square brackets [ ]
#    - by converting any sequence or iterator by invoking list()
#    - \[ \] = empty list
#
# - tuple: one-dimensional, fixed-length, immutable sequence of Python objects  (the objects CAN be mutable!!!)
#  - creation:
#   - with a comma-separated sequence of values
#   - by converting any sequence or iterator by invoking tuple()
#   - ( ) = empty tuple
#
# - dict: flexibly-sized collection of key-value pairs, where key and value are Python objects
#  - creation: {}
#
# - set: unordered collection of unique elements (like dicts, but keys only, no values)
#  - creation: {}

# %% [markdown]
# ----------------------------

# %%
a=[]

# %%
type(a)
# Out:
# list

# %%
b=()

# %%
b=(3,4)
type(b)
# Out:
# tuple

# %%
c=3,4

# %%
type(c)
# Out:
# tuple

# %%
a={}

# %%
b={1,1,1,1,2,2,2,}

# %%
type(b)
# Out:
# set

# %%
b
# Out:
# {1, 2}

# %% [markdown]
# ### check if an object is an instance of a particular type

# %% [raw]
# isinstance() - check if an object is an instance of a particular type

# %%
isinstance(a,(int, dict))
# Out:
# True

# %%
isinstance(a,(int))
# Out:
# False

# %% [markdown]
# ### Object Attributes

# %% [markdown]
# Attributes can be:
# - other Python objects stored “inside” the object
# - methods, attached functions associated with an object which can have access to the object’s internal data.
#
#
# Attributes are accessed via the syntax: __object_name.attribute_name__

# %% [markdown]
# List of attributes depends on Object type!
# How do we know which attributes are available?
# - Autocomplete
# - hasattr()
# - dir()

# %%
c="sttttt"

# %%
hasattr(c, 'capitalize')
# Out:
# True

# %%
dir(c)
# Out:
# ['__add__',
#  '__class__',
#  '__contains__',
#  '__delattr__',
#  '__dir__',
#  '__doc__',
#  '__eq__',
#  '__format__',
#  '__ge__',
#  '__getattribute__',
#  '__getitem__',
#  '__getnewargs__',
#  '__gt__',
#  '__hash__',
#  '__init__',
#  '__init_subclass__',
#  '__iter__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__mod__',
#  '__mul__',
#  '__ne__',
#  '__new__',
#  '__reduce__',
#  '__reduce_ex__',
#  '__repr__',
#  '__rmod__',
#  '__rmul__',
#  '__setattr__',
#  '__sizeof__',
#  '__str__',
#  '__subclasshook__',
#  'capitalize',
#  'casefold',
#  'center',
#  'count',
#  'encode',
#  'endswith',
#  'expandtabs',
#  'find',
#  'format',
#  'format_map',
#  'index',
#  'isalnum',
#  'isalpha',
#  'isascii',
#  'isdecimal',
#  'isdigit',
#  'isidentifier',
#  'islower',
#  'isnumeric',
#  'isprintable',
#  'isspace',
#  'istitle',
#  'isupper',
#  'join',
#  'ljust',
#  'lower',
#  'lstrip',
#  'maketrans',
#  'partition',
#  'replace',
#  'rfind',
#  'rindex',
#  'rjust',
#  'rpartition',
#  'rsplit',
#  'rstrip',
#  'split',
#  'splitlines',
#  'startswith',
#  'strip',
#  'swapcase',
#  'title',
#  'translate',
#  'upper',
#  'zfill']

# %%
c.__hash__()
# Out:
# 1022556178096133645

# %% [markdown]
# ----------------------------

# %% [markdown]
# - dir()
# If called without an argument, return the names in the current scope.
# Else, return an alphabetized list of names comprising (some of) the attributes
# of the given object, and of attributes reachable from it.

# %%
dir()
# Out:
# ['In',
#  'Out',
#  '_',
#  '_12',
#  '_13',
#  '_14',
#  '_16',
#  '_19',
#  '_20',
#  '_25',
#  '_27',
#  '_28',
#  '_29',
#  '_31',
#  '_35',
#  '_38',
#  '_39',
#  '_40',
#  '_41',
#  '_43',
#  '_44',
#  '_45',
#  '__',
#  '___',
#  '__builtin__',
#  '__builtins__',
#  '__doc__',
#  '__loader__',
#  '__name__',
#  '__package__',
#  '__spec__',
#  '_dh',
#  '_i',
#  '_i1',
#  '_i10',
#  '_i11',
#  '_i12',
#  '_i13',
#  '_i14',
#  '_i15',
#  '_i16',
#  '_i17',
#  '_i18',
#  '_i19',
#  '_i2',
#  '_i20',
#  '_i21',
#  '_i22',
#  '_i23',
#  '_i24',
#  '_i25',
#  '_i26',
#  '_i27',
#  '_i28',
#  '_i29',
#  '_i3',
#  '_i30',
#  '_i31',
#  '_i32',
#  '_i33',
#  '_i34',
#  '_i35',
#  '_i36',
#  '_i37',
#  '_i38',
#  '_i39',
#  '_i4',
#  '_i40',
#  '_i41',
#  '_i42',
#  '_i43',
#  '_i44',
#  '_i45',
#  '_i46',
#  '_i5',
#  '_i6',
#  '_i7',
#  '_i8',
#  '_i9',
#  '_ih',
#  '_ii',
#  '_iii',
#  '_oh',
#  'a',
#  'b',
#  'c',
#  'exit',
#  'get_ipython',
#  'quit']

# %%
_i10
# Out:
# 'print ("Hello")'

# %%
_45
# Out:
# 1858195983103903794

# %% [markdown]
# ----------------------------

# %% [markdown]
# ## Referencing an object

# %% [markdown]
# #### When assigning a variable (or name) in Python,  you are creating a reference to the object on the right hand side of the equals sign.

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# When you pass objects as arguments to a function, you are only passing references; no copying occurs.  (Use .copy if you want to copy the content of an object)

# %%
a=[1,2,3]

# %%
b=a

# %%
a.append(4)

# %%
a
# Out:
# [1, 2, 3, 4]

# %%
b
# Out:
# [1, 2, 3, 4]

# %%
id(a), id(b)
# Out:
# (139791794263944, 139791794263944)

# %%
c=a.copy()

# %%
c.append(5)

# %%
a,c
# Out:
# ([1, 2, 3, 4], [1, 2, 3, 4, 5])

# %%
id(c)
# Out:
# 139791794264712

# %%
a=6
b=a
a=7

# %%
a,b
# Out:
# (7, 6)

# %%
id(a), id(b)
# Out:
# (94622776529984, 94622776529952)

# %%
d=6
d=8

# %% [markdown]
# ---------------------
