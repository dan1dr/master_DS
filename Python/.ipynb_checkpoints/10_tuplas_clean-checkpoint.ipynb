# %% [markdown]
# # Data structures - Tuples

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
tup=4, 5, 6
tup

# %%
tup2=tuple('string')
tup2

# %% [markdown]
# tuple from list:

# %%
tuple([4, 0, 2])

# %%
tup3=tuple(['string','me'])
tup3

# %%
nested_tup=(4, 5, 6), (7,8), ('A', 8, 'abcd')
nested_tup

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
tup2=tuple('string')
tup2[0]

# %%
print(tup2[:3])
print(tup2[2:4])
print(tup2[4:])

# %%
print(tup2[::2])
print(tup2[-1])
print(tup2[::-1])

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
tup=tuple(['foo', [1, 2], True])
tup

# %%
tup[2]

# %%
tup[2]=False

# %%
tup[1]

# %%
tup[1].append(4)

# %%
tup

# %%
tup[1].insert(1,14)

# %%
tup

# %% [markdown]
# __Tuples can be concatenated using the + operator to produce longer tuples__

# %%
tup=tuple(['foo',[1,2], True])
tup=tup + tuple([23,45]) + tuple('Whynot') + tuple([[23,45]]) + tuple(['YES'])
tup

# %%
print(id(tup))
tup +=tuple([True])
print(id(tup))
tup

# %% [markdown]
# __common error__

# %%
tup + ('bar')

# %%
type(('bar',))

# %% [markdown]
# __Multiplying a tuple by an integer, has the effect of concatenating together that many copies of the tuple.__

# %%
tup=tuple(['foo',[1,2], True])
tup * 2

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
a=[1,2,3]; b=[23]; c=50; d=['Txt']; e='aa'
tup=tuple([a,b,c,d,e])
tup

# %%
print(id(a),id(b),id(c))

# %%
tup2=tup*2
tup2

# %%
a[0]=4; b.append(-23); c=7; d[0]='YES'; e='NO WAY DUDE'

# %%
print(id(a),id(b),id(c))

# %%
tup2

# %% [markdown]
# # Unpacking Tuples

# %%
def mitupla(tup1):
    return tup1
myquery = mitupla((2,3))
print(myquery)
a,b=mitupla(2,3)
print(a,b)
# Out:
# (2, 3)
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-9-714614514ce0> in <module>
#       3 myquery = mitupla((2,3))
#       4 print(myquery)
# ----> 5 (a,b)=mitupla(2,3)
#       6 print(a,b)
#
# TypeError: mitupla() takes 1 positional argument but 2 were given

# %%
tup = (4,5,6)
a, b, c = tup
b

# %%
tup2=4, 5, (6, 7)
a, b, (c, d)=tup2
d

# %%
a, b, cd=tup2
cd

# %% [markdown]
# __Using this functionality it’s easy to swap variable names__

# %%
a,b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-2fbdd1b4fa70> in <module>
# ----> 1 a,b
#
# NameError: name 'a' is not defined

# %%
a, b=b,a
a, b
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-14-2cc3de4686c7> in <module>
# ----> 1 a, b=b,a
#       2 a, b
#
# NameError: name 'b' is not defined

# %%
a=4; b=5
(a,b)=(b,a)

# %%
a,b
# Out:
# (5, 4)

# %% [markdown]
# **Exercise:** Try this with lists!

# %%
list1 = [a,b]
a,b=b,a
a,b
# Out:
# (5, 4)

# %% [markdown]
# # Methods

# %% [markdown]
# index() = return first index of value
# count() = counts the number of occurrences of a value

# %%
a=(1, 2, 2, 2, 3, 4, 2)
a.count(2)

# %%
a.index(2)

# %%
2 in a

# %%
3434 in a

# %%
b=('this', 'is', 'my', 'home')
b.count('i')
# Out:
# 0

# %%
b.count('is')
# Out:
# 1

# %%
b.index('i')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-24-e6c84431d6f4> in <module>
# ----> 1 b.index('i')
#
# ValueError: tuple.index(x): x not in tuple

# %% [markdown]
# --------

# %% [markdown]
# A tuple created from dictionary will only retain keys!

# %%
tuple({'igor':'ivana', 'boris':'goran'})

# %% [markdown]
# # ZIP FUNCTION
#
# “pairs” up the elements of a number of lists,tuples, or other sequences, to create a sequence of tuples
#
# __pairing is ended when the shortest sequence is exhausted__
#
# returns a zip object which is in fact an iteretor

# %%
seq1=[1, 2, 3, 4, 5, 6]
seq2=(7, 8, 9, 10)
seq3=[True, False, True]

# %%
type(zip(seq1, seq2, seq3))
# Out:
# zip

# %%
table=tuple(zip(seq1, seq2, seq3))
table
# Out:
# ((1, 7, True), (2, 8, False), (3, 9, True))

# %%
for i,element in enumerate(['a', 'b', 'c']):
    print(i,element)
# Out:
# 0 a
# 1 b
# 2 c

# %%
indices = [0,1,2]
lista = ['a', 'b', 'c']
tuple.zip(indices,lista)
for i,element in enumerate(['a','b'])#...
# Out:
#   File "<ipython-input-34-05422ec7a9f1>", line 4
#     for i,element in enumerate(['a','b'])#...
#                                              ^
# SyntaxError: invalid syntax

# %% [markdown]
# # UNZIP is also done by ZIP function

# %%
seq1b, seq2b, seq3b=zip(*table)

# %%
seq1b, seq2b, seq3b
# Out:
# ((1, 2, 3), (7, 8, 9), (True, False, True))

# %% [markdown]
# __accesing the elements of the table__

# %%
for i in table:
    print(i)
# Out:
# (1, 7, True)
# (2, 8, False)
# (3, 9, True)

# %%
for a,b,c in table:
    print(a)
# Out:
# 1
# 2
# 3

# %% [markdown]
# # Enumerate
#
# __It’s common when iterating over a sequence to want to keep track of the index of the current item__
# __enumerate() returns a sequence of (i, value) tuples__

# %%
counter=0
for val in range(10, 20):
    print(counter, val)
    counter +=1

# %%
for counter, val in enumerate(range(10, 20)):
        print(counter, val)

# %% [markdown]
# * useful especially when constructing a dict
# * reversed() = iterates over the elements of a sequence in reverse order

# %%
for counter, val in enumerate(reversed(range(10, 20))):
        print(counter, val)
