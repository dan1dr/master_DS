# %% [markdown]
# ## Scalar Types

# %% [markdown]
# - int = Signed integer with maximum value determined by the platform.
# - long = Arbitrary precision signed integer. Large int values are automatically converted to long.
# - float = floating point number
# - str = String type
# - bool = A True or False value
# - None = The Python “null” value (only one instance of the None object exists)

# %% [markdown]
# ----------------------

# %% [markdown]
# The size of the integer which can be stored as an int is dependent on your platform (whether 32 or 64-bit), but Python will transparently convert a very large integer to long, which can store arbitrarily large integers.

# %%
k = 121279837249872398473298749328749328749328749328749 ** 40
k
# Out:
# ...

# %% [markdown]
# ----------------------

# %%
import math
math.factorial(8)
# Out:
# 40320

# %% [markdown]
# ## Strings

# %% [markdown]
# You can write string literal using either single quotes ' or double quotes "
# For multiline strings with line breaks, you can use triple quotes, either ''' or """

# %% [markdown]
# ### El carácter `\`

# %% [markdown]
# `\t` es tabulado
# `\n` es nueva linea

# %%
print("this is in \nnew line")
# Out:
# this is in
# new line

# %%
print("this is in \n new line and with \t tab")
# Out:
# this is in
#  new line and with 	 tab

# %% [markdown]
# ### Métodos de strings

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# __Accesing the elements of the string__

# %%
a="this is a string"
print(a.count("s"))
# Out:
# 3

# %%
s = "let's see how many s's this text has"
print(s.count("s"))
# Out:
# 6

# %%
a[0]
# Out:
# 't'

# %%
s[11]
# Out:
# 'o'

# %% [markdown]
# __Strings are immutable!!
# You cannot modify a string without creating a new string
# Even when using a replace function__

# %%
a[0]='y'
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-32-456d321e84c3> in <module>
# ----> 1 a[0]='y'
#
# TypeError: 'str' object does not support item assignment

# %% [markdown]
# ### Concatenar strings

# %%
id(a)
# Out:
# 139977178164160

# %%
a=a+'this is new'
a
# Out:
# 'that is a stringthat is newthis is new'

# %%
id(a)
# Out:
# 139977413991568

# %%
b = a.replace('this', 'that')
print(b)
# Out:
# that is a stringthat is newthat is new

# %%
print(a.replace('this', 'that'))
# Out:
# that is a stringthat is newthat is new

# %%
print(a)
# Out:
# that is a stringthat is newthis is new

# %%
id(a)
# Out:
# 139977413991568

# %%
a
# Out:
# 'that is a stringthat is newthis is new'

# %%
a=a.replace('this', 'that')

# %% [markdown]
# __find vs index vs count__

# %%
a.find('that')
# Out:
# 0

# %%
a.find('a')
# Out:
# 2

# %%
a.find('1')
# Out:
# -1

# %%
a.index('this')
# Out:
# 27

# %%
a
# Out:
# 'that is a stringthat is newthis is new'

# %%
a.count('t')
# Out:
# 6

# %%
a.count('th')
# Out:
# 3

# %%
len(a)
# Out:
# 38

# %%
a.__sizeof__()
# Out:
# 87

# %% [markdown]
# __strip vs rstrip vs lstrip__

# %%
"     qweewe qw       jkgkjhkjh. jhkjhkj     kjlkjl   ".strip()
# Out:
# 'qweewe qw       jkgkjhkjh. jhkjhkj     kjlkjl'

# %%
"        jkgkjhkjh. jhkjhkj     kjlkjl   ".rstrip()
# Out:
# '        jkgkjhkjh. jhkjhkj     kjlkjl'

# %%
"     qweewe qw       jkgkjhkjh. jhkjhkj     kjlkjl   ".lstrip()
# Out:
# 'qweewe qw       jkgkjhkjh. jhkjhkj     kjlkjl   '

# %%
my_name = "Toni Almagro"
my_name_from_Juan = "toni Almagro"
my_name_from_Juan.strip().lower() == my_name.strip().lower()
# Out:
# True

# %% [markdown]
# __split vs splitlines vs join__

# %%
cadena= "this is my text"
cadena[:-1]
# Out:
# 'this is my tex'

# %%
resultado=""
separador = "^"
for word in cadena.split():
    resultado=resultado + word + separador
#Remove final ^
resultado = resultado[:-1]
print(resultado)
# Out:
# this^is^my^text

# %%
"this is my text".split()
# Out:
# ['this', 'is', 'my', 'text']

# %%
"this is my text".split("t")
# Out:
# ['', 'his is my ', 'ex', '']

# %%
"this^is^my^ex".split("^")
# Out:
# ['this', 'is', 'my', 'ex']

# %%
k="123^his is my ^ex^123".split("^")

# %%
k
# Out:
# ['123', 'his is my ', 'ex', '123']

# %%
' '.join(k)
# Out:
# '123 his is my  ex 123'

# %%
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-107-008fafde7dac> in <module>
# ----> 1 z = k.replace('t', '123')
#       2 z
#
# AttributeError: 'list' object has no attribute 'replace'

# %%
a[:]
# Out:
# 'that is a stringthat is newthis is new'

# %%
pal = "dabale arroz a la zorra el abad"

# %%
pal[5::-1]
# Out:
# 'elabad'

# %% [markdown]
# ### String indexing and slicing

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
kk = {0}
print(type(kk))
# Out:
# <class 'set'>

# %% [markdown]
# # Booleans

# %%
bool(0)
# Out:
# False

# %%
bool(1)
# Out:
# True

# %%
bool('thst')
# Out:
# True

# %%
bool(None)
# Out:
# False

# %%
bool(True or False)
# Out:
# True

# %%
bool(True and False)
# Out:
# False

# %%
True or False
# Out:
# True

# %%
True or lksfjglkjfdglkjfdglkjfdldkgjdflkjgld
# Out:
# True

# %%
a=3
b=3
c=a+b
c

# %% [markdown]
# -----------------------

# %% [markdown]
# # Quick Exercises 2
#
# * Write a function to calculate the number of words, number of lines, and length of a string the same way the wc command does in the command line

# %%
text = "estaba yo, vendiendo rulas\n para pillarme un pico\n de una papelera salen dos monillos\n me dicen que le..."

# %%
print(text)
print(len(text))
print(len(text.split(" ")))
print(len(text.split("\n")))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-4-0e76369d85d9> in <module>
# ----> 1 print(text)
#       2 print(len(text))
#       3 print(len(text.split(" ")))
#       4 print(len(text.split("\n")))
#
# NameError: name 'text' is not defined

# %% [markdown]
# * Write a Python program to remove the nth index character from a string. If the input string is empty print warning.

# %%
def remove(string, n):
    if string == "":
        print("Warning")
    first = string[:n]   
    last = string[n+1:]  
    return first + last
        
string=input("Enter string:")
n=int(input("Enter the index of the character to remove:"))
print("Modified string:")
print(remove(string, n))
# Out:
# Enter string:
# Enter the index of the character to remove:2
# Modified string:
# Warning
